# %% [markdown]
# <a href="https://colab.research.google.com/github/ai-socialimpact/LLMWiki-NGO-Humaninloop/blob/main/Wiki_QA_v_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Design  of Wiki QA System
#
#
# Input to Step 1:
#
#  Router Index https://github.com/ai-socialimpact/LLMWiki-NGO-Humaninloop/blob/main/WikiContents/WikiContentVersions/WikiVer2/index_stage_routing_protocol.md
#
#
# ## 3 Step QA system (Router LLM call , then the QA LLM call):
#
# 1. Step 1: Router (LLM Call) - identifies which topic files to look up using a 3-step reasoning and the Router Index
#
#   Output of Router: list of topicX.md
#
#  2. Based on identified topic files from Step 1, Read the Identified Topic files and prepare to send to Step 3
#
#  3. Extractive Question answering LLM call - Use LLM to extract answers from topicX.md contents

# %%
import os
import shutil

if True==False:
  directory_to_delete = "/content/LLM_Wiki_Vault"

  # Check if the directory exists before attempting to delete
  if os.path.exists(directory_to_delete):
      shutil.rmtree(directory_to_delete)
      print(f"Directory '{directory_to_delete}' and its contents deleted successfully.")
  else:
      print(f"Directory '{directory_to_delete}' does not exist.")

# %%
# @title
OPENAI_KEY= '' # load from Colab Secrets

# %%
# !mkdir -p /content/LLM_Wiki_Vault/wiki/

# %%
# !unzip '/content/wiki.zip' -d /content/LLM_Wiki_Vault/
# Out:
# Archive:  /content/wiki.zip
# replace /content/LLM_Wiki_Vault/wiki/anemia_during_pregnancy.md? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/LLM_Wiki_Vault/wiki/anemia_during_pregnancy.md
#   inflating: /content/LLM_Wiki_Vault/wiki/breastfeeding_guidance.md
#   inflating: /content/LLM_Wiki_Vault/wiki/breastfeeding_special_conditions.md
#   inflating: /content/LLM_Wiki_Vault/wiki/childbirth_and_newborn_care.md
#   inflating: /content/LLM_Wiki_Vault/wiki/child_growth_and_malnutrition.md
#   inflating: /content/LLM_Wiki_Vault/wiki/complementary_feeding_6_to_24_months.md
#   inflating: /content/LLM_Wiki_Vault/wiki/general_child_care_and_development.md
#   inflating: /content/LLM_Wiki_Vault/wiki/government_cash_benefit_schemes.md
#   inflating: /content/LLM_Wiki_Vault/wiki/government_free_service_schemes.md
#   inflating: /content/LLM_Wiki_Vault/wiki/immunization_rules_and_exceptions.md
#   inflating: /content/LLM_Wiki_Vault/wiki/immunization_schedule_and_basics.md
#   inflating: /content/LLM_Wiki_Vault/wiki/index_stage_routing_protocol.md
#   inflating: /content/LLM_Wiki_Vault/wiki/local_health_services_and_schedules.md
#   inflating: /content/LLM_Wiki_Vault/wiki/pregnancy_care_and_checkups.md
#   inflating: /content/LLM_Wiki_Vault/wiki/pregnancy_nutrition_and_diet.md
#   inflating: /content/LLM_Wiki_Vault/wiki/vaccine_side_effects_and_reactions.md

# %%
#  STEP 1:
# =====================================================================

import os
import json
from typing import List, Set
from pydantic import BaseModel, Field, field_validator, ValidationError
from google.colab import userdata


try:
    import openai
    from openai import types
except ImportError:
    print("  SDK missing from active runtime. Initializing pipeline pip deployment hooks...")
    # !pip install -q openai
    import openai
    from openai import types


OPENAI_TOKEN_AUTHENTICATOR = OPENAI_KEY

openai_client = openai.OpenAI(api_key= OPENAI_KEY )
print("  authenticated.")



#  local path
WIKI_VAULT_DIR = "/content/LLM_Wiki_Vault/wiki/"

def get_allowed_topic_files_manifest(wiki_dir: str) -> Set[str]:
    """
      scans the   folder path   and populates a strict local memory hash-set of valid, available topic files.
    """
    if not os.path.exists(wiki_dir):
        print(f"⚠️  Directory Alert: Target vault path '{wiki_dir}' does not exist on disk yet. "
              f"Please ensure you drop your exported 'wiki/' folder inside the Colab file storage directory.")
        return set()

    all_files_found = [f for f in os.listdir(wiki_dir) if f.endswith(".md")]
    allowed_topics_set = {f for f in all_files_found if f not in ["index.md", "index_detailed.md", "log.md"]}
    return allowed_topics_set

ALLOWED_WIKI_FILES = get_allowed_topic_files_manifest(WIKI_VAULT_DIR)
print(f" [Step 1 Status]: Harvested allowed local topic files footprint: {ALLOWED_WIKI_FILES}")



class ChatbotRoutingDecision(BaseModel):
    """
    Enforces   contract for the Router  .
     Reasoning out put thinking based on contents of index_stage_routing_protocol.md.
    """
    router_reasoning_log: str = Field(
        ...,
        description=(
            "3-STAGE REASONING WORKFLOW:\n"
            "STAGE 0 (Language translation): Translate input question from Hindi to English query. Identify user_intent and topic \n "
            "STAGE 1 (Protocol Selection): Match query signature parameters against SECTION_1_ROUTING_DIRECTIVES. Identify core command (Generic Pooling, Milestone Isolation, etc).\n"
            "STAGE 2 (Inclusion Shortlisting): Cross-reference intent tokens against SECTION_2_INCLUSION_KEYWORDS. List all potential filename candidates matching the intent.\n"
        )
    )
    user_intent: List[str] = Field(
        ...,
        description=" Extracted query intent from Enduser question "
    )
    topic_focus: List[str] = Field(
        ...,
        description="  Extracted topic focus from Enduser question"
    )
    target_topic_slugs: List[str] = Field(
        ...,
        description="The clean, final array containing the exact filenames."
    )
    extracted_intent_tags: List[str] = Field(
        ...,
        description="A flat list of discovered lowercase alphanumeric metadata tracking keywords isolated out of the query string."
    )
    feedback_on_end_user_question: List[str] = Field(
        ...,
        description="Feedback on the Enduser Question. If the Enduser question is generic, provide feedback to enduser to frame a better question with an example question. This will help illiature enduser to ask specific questions."
    )
    clarity_of_end_user_question: List[str] = Field(
        ...,
        description="Is the Enduser Question clear and comprehensive enough to find an answer. Does the Question have all the required information to provide answer?"
    )
    assumptions_made_about_user: List[str] = Field(
        ...,
        description="Is there any assumptions made about the user or user question?"
    )



    @field_validator('target_topic_slugs')
    @classmethod
    def validate_filenames_against_disk_footprint(cls, checked_slugs_list: List[str]) -> List[str]:
        """
        Dynamic  Gatekeeper: Verifies that every single file entry returned by the
        model exists physically as an hard disk -   This will force LLM to NOT to hallunicate names of files. 100% Reduction of file name LLM hallunication
        """
        #
        if not ALLOWED_WIKI_FILES:
            return checked_slugs_list

        for single_slug in checked_slugs_list:
            clean_slug_string = single_slug.strip()

            #  Validation :  h
            if clean_slug_string not in ALLOWED_WIKI_FILES:
                raise ValueError(
                    f"Router attempted to select file token '{clean_slug_string}', "
                    f"which does not exist physically inside the verified directory bounds: {ALLOWED_WIKI_FILES}"
                )
        return checked_slugs_list

print("🧬 [Step 1 Status]: Dynamic Pydantic schema validation contract matrices locked and verified.")
# Out:
#   authenticated.
#  [Step 1 Status]: Harvested allowed local topic files footprint: {'complementary_feeding_6_to_24_months.md', 'general_child_care_and_development.md', 'local_health_services_and_schedules.md', 'breastfeeding_special_conditions.md', 'anemia_during_pregnancy.md', 'pregnancy_care_and_checkups.md', 'index_stage_routing_protocol.md', 'vaccine_side_effects_and_reactions.md', 'government_free_service_schemes.md', 'pregnancy_nutrition_and_diet.md', 'immunization_rules_and_exceptions.md', 'child_growth_and_malnutrition.md', 'government_cash_benefit_schemes.md', 'immunization_schedule_and_basics.md', 'childbirth_and_newborn_care.md', 'breastfeeding_guidance.md'}
# 🧬 [Step 1 Status]: Dynamic Pydantic schema validation contract matrices locked and verified.

# %% [markdown]
# ##  LLM Hullinication prevention technique:
# ### ChatbotRoutingDecision.target_topic_slugs  rejects any LLM hullinications   : self-healing loop to intercept Pydantic ValidationErrors
#
# ensure the LLM returns valid file names

# %% [markdown]
# # NGO community Slang mapping
#
# ### based on NGO community's slag  (use Gliffic Question log to understand this), this could be customized for the NGO : BILINGUAL INTENT TRANSLATION MATRIX:

# %%
# 🧭 STEP 2:  ROUTER in LLM Wiki QA system
# =====================================================================



SYSTEM_INSTRUCTION_ROUTER = """You are an Elite Bilingual Technical Router for a high-stakes public health chatbot network deployed in Mumbai slum communities.

Your sole mission is to ingest conversational text questions written in Hindi or Hinglish shorthand, translate their core operational intent,
and cross-reference them against index_stage_routing_protocol.md to select the exact target markdown files needed to resolve the query.

Inputs:
1. Input question from user
2. The definitive master semantic index manifest table array, index_stage_routing_protocol.md.
The index_stage_routing_protocol.md provides 2 important look-up tables: SECTION_1_ROUTING_DIRECTIVES, SECTION_2_INCLUSION_KEYWORDS.
3. BILINGUAL INTENT TRANSLATION MATRIX for understanding user questions in Bilingual/Hindi, especially the community Hindi slang

Important Guidance and Context:
Apply step by step reasoning to shortlist/deduce the most appropriate filenames that is likely to contain the answer for user's input question.
The required contextual data for reasoning is provided below in index_stage_routing_protocol.md.
Apply the 3-STAGE REASONING WORKFLOW step by step to shortlist/deduce the most appropriate filenames.
Your output of shortlisted filenames will be used by a downstream agent. The downstream agent will read the shortlisted files to extract answer for the user's question.
Your task is just to identify these filenames and output the array of excat filenames.

MANDATORY 3-STAGE REASONING WORKFLOW:
1. STAGE 0 (Language translation and Extraction of User Intent, Topics, keywords):  Translate enduser's question from Hindi to English query, and identify user's intent(user_intent) and the topic of enduser's question. Infer the user's broader situation (e.g. health status, lifecycle stage) and jot down the assumptions (assumptions_made_about_user). The user_intent and topic_focus of the Enduser question can be mapped using the taxonomy listed in the index_stage_routing_protocol.md.To analyze enduser's questions with any local hindi slang, refer BILINGUAL INTENT TRANSLATION MATRIX. The identified user_intent and topic_focus of the enduser's question, and extracted keywords will be useful inputs for the next reasoning step.
2. STAGE 1 (Protocol Selection):   Apply step by step thinking to reason out the most appopriate choices for the user_intent and topic_focus by analyzing different possible choices from SECTION_1_ROUTING_DIRECTIVES.
3. STAGE 2 (Inclusion Shortlisting): Cross-reference user_intent and the translated English enduser's query against SECTION_2_INCLUSION_KEYWORDS. List all potential filename candidates matching the enduser's question and keywords.



IMPORTANT RULE WHILE EXECUTING 3-STAGE REASONING WORKFLOW:
Analyze if the Question contains enough information to answer. If Question doesn't contain enough information (not comprehensive enough or not clear or out of scope), jot down feedback_on_end_user_question and clarity_of_end_user_question.
If in doubt, understand if the question has enough clartiy (clarity_of_end_user_question).
If in doubt during reasoning the most appopriate filename choices from SECTION_1_ROUTING_DIRECTIVES, instead use SECTION_2_INCLUSION_KEYWORDS to shortlist the most appropriate filenames.
If in doubt, err on the side of including the filename in the output array.
If in doubt during the step of 'Stage 1 Protocol Selection', err on the side of providing wider shotlist of appopriate choices.
If in doubt during the step of 'Stage 2 Inclusion Shortlisting', err on the side of providing wider shotlist of appopriate choices.

RULE TO HANDLE OUT OF SCOPE User QUESTION:
1. If the user question is extemely outside scope of the KB, it is OK to return empty.
2. If the user question is slightly outside scope, but there could a related KB, return the related filenames.

BILINGUAL INTENT TRANSLATION MATRIX:
   - 'khurak',  'sabji' ->   nutritional and dietary keywords
   - 'jaanch' ->    checkup, diagnostics
   -  'wajan badhane'   ->   pediatric development horizons
   - 'safed pani', 'khoon kam', 'bukhar', 'soojan', 'dard'  ->  danger signs, treatment, and clinical severity nodes.
   - 'labh'(Schemes/Benefits) ->  government scheme containers

Expected Output:
The expected output is array containing the exact filenames of the shorlisted/deduced files that contain the answer to the user's query.

Other fields in Output, 'feedback_on_end_user_question': Feedback on the Enduser Question to help illiature enduser to ask specific questions. If the Enduser question is generic, provide feedback to enduser to frame a better question by suggesting an example question. Illitature endusers may not know how to frame a frame a better question. Coach them gentle that asking a more specific question will help them find a better answer.
For example, if an illiature enduser asked a question 'what to eat during pregnancy', suggest how to frame a better question with reasoning 'what to eat during 1st trimester of pregnancy. My health condition is normal'. Reason: Recommendation vary based on trimester and health condition. Help the illitrature enduser to ask a more specific question.
For example, if an illiature enduser asked a question 'my child is having fever', suggest to frame a better question ' my child is 3 months old. She is having high fever and mild cough for 2 days. what to feed'. Reasoning: Questions with specific information about age & health condition can yeild better answers.


Provide your evaluation strictly within the requested structured Pydantic layout format with zero narrative text filler."""

TEMPLATE_ROUTER = """Review the definitive master semantic index manifest table array listed below:

=== MASTER index_stage_routing_protocol.md CONFIGURATION CONTRACT ===
{index_detailed_content_string}
========================================================

Analyze the user's incoming conversational question string provided below:
User Query: "{user_whatsapp_query}"

Your task is to run a strict manifest logic alignment check. Isolate the target topic file slug path array required to synthesize a fact-checked response.
Return your decision payload within the required JSON template contract."""

# %% [markdown]
# ## Router

# %%
import os
from pydantic import ValidationError

def execute_gpt_precision_router_with_retry(
    openai_client_instance,
    wiki_dir: str,
    user_query: str,
    target_gpt_model: str = "gpt-4o-mini",
    max_healing_retries: int = 3
) -> dict:
    """
    Stage 1: Evaluates a user's WhatsApp query against index .md.
    Executes for the specific model passed via the target_gpt_model parameter.
    Uses an internal self-healing loop to intercept Pydantic ValidationErrors,
    feeding structural corrections straight back to OpenAI dynamically.
    """
    print(f"\n[Stage 1 Router] \u2B41 Ingesting input query: '{user_query}' using model '{target_gpt_model}'...")

    # 1. Resolve and access pre-compiled index_detailed.md manifest sheet
    detailed_index_path = os.path.join(wiki_dir, "index_stage_routing_protocol.md")
    if not os.path.exists(detailed_index_path):
        raise FileNotFoundError(
            f"❌ Stage 1 Routing Failure: Detailed semantic index matrix is missing at path '{detailed_index_path}'. "
            "Please ensure you drop your exported 'wiki/' folder inside the Colab file storage directory."
        )

    with open(detailed_index_path, 'r', encoding='utf-8') as f_idx:
        index_manifest_text = f_idx.read()

    # 2. Template variables cleanly into the global prompt constant structure
    base_user_prompt = TEMPLATE_ROUTER.format(
        index_detailed_content_string=index_manifest_text,
        user_whatsapp_query=user_query
    )

    # Initialize messages list for conversation history tracking during retry turns
    execution_messages = [
        {"role": "system", "content": SYSTEM_INSTRUCTION_ROUTER},
        {"role": "user", "content": base_user_prompt}
    ]

    attempt = 0

    # 3. Self-Healing Resilient Execution Loop
    while True:
        try:
            attempt += 1

            # Dynamic kwargs assembly to safely manage API variations
            api_kwargs = {
                "model": target_gpt_model,
                "messages": execution_messages,
                "response_format": ChatbotRoutingDecision,
                "seed": 42,
                "temperature": 0 # Default to 0 for deterministic routing
            }

            # Apply reasoning budget strictly to the GPT-5.6 flagship tier
            if "gpt-5" in target_gpt_model:
                api_kwargs["reasoning_effort"] = "high"
                # Remove temperature for GPT-5.6 models if not supported
                if "temperature" in api_kwargs:
                    del api_kwargs["temperature"]


            #print('DEBUG')
           # print(api_kwargs)
            #print('DEBUG')
            # Execute LLM call using Structured Outputs (.parse)
            response = openai_client_instance.beta.chat.completions.parse(**api_kwargs)

            # 🛠️ Pull the response from gpt
            parsed_choice_object = response.choices[0].message.parsed

            if parsed_choice_object is None:
                raise ValueError("❌ Stage 1 Router Fault: OpenAI response container failed to parse against the schema contract layout.")

            routing_decision_payload = parsed_choice_object.model_dump()
            print(f"[Stage 1 Router] ✅ Structural routing cleared successfully on attempt [{attempt}].")
            return routing_decision_payload

        except (ValidationError, ValueError) as tracking_error:
            print(f"⚠️ [Pydantic/Value Interception]: Filename validation anomaly caught on attempt [{attempt}/{max_healing_retries}].")
            error_message = str(tracking_error)
            print(f"    Validation Log Detail: {error_message}")

            # Fallback if maximum corrections are breached
            if attempt >= max_healing_retries:
                print("💥 [Stage 1 Router]: Maximum self-healing attempts breached. Escalating exception to app core.")
                raise tracking_error

            # Capture the raw model response text to append to history
            raw_faulty_output = response.choices[0].message.content if ('response' in locals() and response.choices) else "{}"

            # Append messages stack
            execution_messages.append({"role": "assistant", "content": raw_faulty_output})

            corrective_feedback_prompt = (
                f"CRITICAL STRUCTURAL FAULT ENCOUNTERED:\n"
                f"Your previous response generated an invalid configuration/filename array triggering this validation error:\n"
                f"{error_message}\n\n"
                f"Please completely re-evaluate the allowed file headers inside index_detailed.md. "
                f"Correct the file slug arrays to match the ground-truth names exactly, and output a valid data contract."
            )
            execution_messages.append({"role": "user", "content": corrective_feedback_prompt})

# %%
# =====================================================================
# 📋 STEP 3 : SNEHA DIDI SYNTHESIS PROMPT
# =====================================================================

SYSTEM_INSTRUCTION_SYNTHESIS = """

You are SNEHA DIDI, an empathetic, safe, and authoritative chatbot delivering public health advice via WhatsApp to women located in low economic urban settlements in Mumbai.

The women asking questions may have limited literacy, and will send messages with typos or incomplete information or in Hindi.
You must format your responses using simple and casual words that a 5-year-old could easily understand.
Your response must be comprehensive, yet highly concise—restricted to a MAXIMUM of 4 to 7 text lines in total.

GROUNDING RULES: The answers has to be 100% grounded on the attached context chunks. Extract the answers from the provided ground-truth wiki context blocks.

Step to find the answer:
1. Understand the User Question , target_topic_slugs
2. Review the fact-checked ground-truth wiki context blocks attached below.
3. Extract the answer from the provided ground-truth wiki context blocks.
4. Adhere to the GROUNDING RULES.
5. Format output as per EXPECTED OUTPUT STYLE AND LANGUAGE RULES

Step to handle generic question:
1. Understand the User Question
2. Understand the user_intent, topic_focus, extracted_intent_tags
3. Understand the feedback_on_end_user_question
4. Understand the target_topic_slugs
5. Understand the router_reasoning_log
6. If the user's question is generic (e.g. pregnancy) and doesn't include any specific context (e.g. trimester/anemia status), answer the generic question with a disclaimer that the question is generic, and say you can provide a more appropriate answer if you know the specific context, and provide suggestions on how to frame effective specific question to help the illitrate enduser.
7. Provide clear holistic answers to the user's question to give unambigious answer. Refer feedback_on_end_user_question and  router_reasoning_log. For example, include the context about when the answer is valid. For example, if you suggest a tablet dosage, state when the answer is valid such Take x amount of tablet, if you have this health condition.
8. While answering to a question, share any assumptions you make. Use the router_reasoning_log to state any assumptions you made about user intent. For example, if the question was about 3rd trimester diet, state your assumption that the provided answers are for normal mothers and NOT for anemic mother.
9. At the end of answer, add a extra line about the assumptions made or the user intent or topic using the router_reasoning_log. This removes any ambiguity in context about the provided answer for an illitrate. In other words, include the boundaries conditions about when the answer is valid. For example, if you suggest a tablet dosage, state when the answer is valid such Take x amount of tablet, if you have this health condition.
10. Always adhere to GROUNDING RULES.
11. If there are multiple questions or multiple topics, try to answer every question
12. After answering the question,  add helpful tips based on feedback_on_end_user_question to help frame a better question, and encourge user to include specific info (e.g. trimester, anemic status, etc).


EXPECTED OUTPUT STYLE AND LANGUAGE RULES:
1. LANGUAGE-MATCHING PARSING MANDATE:
   - If the user query is written in Hindi (Devanagari script), you MUST strictly respond entirely in Hindi using the Devanagari script.
   - If the user query is written in Romanized Hindi (Hinglish/English script with transliterated Hindi words, e.g., 'khana', 'bacha', 'dard'), you MUST strictly respond entirely in Romanized Hindi.
   - If the user query is asked in English, you MUST strictly respond entirely in Romanized Hindi (Hinglish).

2. ABSOLUTE CONTEXTUAL GATEKEEPER LOCK:
   You are STRICTLY FORBIDDEN from responding from the Internet, or guessing.
   - If the answer cannot be found inside the provided documents, you MUST politely respond by outputting exactly: "Mere paas iska uttar nahin hai. Kripya apne najdik ke health facility/doctor/officer se sampark karein. [The Wiki doesn't have any answers to this question] "

3. BRIEF CONVERSATIONAL SHORT-CIRCUITS:
   If the query consists only of emojis, generic greetings, or acknowledgment words (like 'yes', 'thank you', 'ok', 'ji', 'G', 'hi', 'bye', 'theek hai'), respond back briefly and warmly in the same language alignment matching their greeting message.

EXPECTED OUTPUT LENGHT:
Your response must be comprehensive, yet highly concise—restricted to a MAXIMUM of 4 to 5 text lines in total.


Format numbers and core milestones cleanly using scannable bullet characters, keeping the text extremely short and compact for low-bandwidth mobile viewports."""



print("✅ [System Migration Complete]: Step 3 Synthesis prompt locked to SNEHA DIDI production style.")
# Out:
# ✅ [System Migration Complete]: Step 3 Synthesis prompt locked to SNEHA DIDI production style.

# %%
# =====================================================================
# 📋 STEP 3 UNIFIED: SNEHA DIDI SYNTHESIS PROMPT VARIATION
# =====================================================================

SYSTEM_INSTRUCTION_SYNTHESIS = """

You are a Question Answering Expert.
Your task is to answer the EndUser's question from the provided context (ground-truth wiki content blocks).
You provided grounded answers from the provided context (ground-truth wiki content blocks).

Your personality:
You are SNEHA DIDI, an empathetic, safe, and authoritative Question Answering Chatbot delivering public health advice via WhatsApp to women located in low economic urban settlements in Mumbai.
The women asking questions may have limited literacy, and will send questions with typos or incomplete information or in Hindi.

Anatomy of Your inputs:
1. Incoming EndUser Query and Extracted entities from the EndUser Query:
Incoming End User Query: EndUser Question.
Extracted Intent of User Question: user_intent, extracted_intent_tags, topic_focus.
Comments about level of clarity and Comprehensiveness of the EndUser Question: clarity_of_end_user_question
Assumptions about the EndUser sitation: assumptions_made_about_user
Advice to the illitrature EndUser to frame a better Question next time: feedback_on_end_user_question

2. The reasoning log:
Some thoughts about how to deduce the answer from the provided topics: router_reasoning_log

3. The Context to answer from:
The count on the number of topics in the supplied Wiki Context: count_of_topics_in_context
The list of topics (filenames) in the context: list_of_topics_in_context
The context itself: Set of Ground Truth Wiki File Contents, organized in a set of markdown files

GROUNDING RULES: The answers has to be 100% grounded on the attached context chunks. Extract the answers from the provided ground-truth wiki context blocks.

Step to find the answer:
1. Understand the EndUser Question.  Understand the EndUser question in the context of the use case by reading EndUser Question, user_intent, topic_focus, clarity_of_end_user_question.
2. Review the provided Context to answer from. The Context is fact-checked ground-truth Wiki content. (a count of the number of topics in the Context, the list of topics in the Context, the Wiki content organized by topic)
3. Answer the question from the provided Context (Wiki Content).
4. Adhere to the GROUNDING RULES while extracting the answers from the fact-checked ground-truth Wiki Content.
5. Validate the answer after reading the Context again (You may be supplied multiple Wiki Content Blocks, where the contexts are organized by topic-wise structure) .
6. Compile a holistic answer by adding the context in which the provided answer is valid.
7. Minimize communication gap by sharing the assumptions made about the user's question (refer assumptions_made_about_user).
8. Summarize and compile the answer in crisp, consise, short sentences.
9. Format output as per EXPECTED OUTPUT STYLE AND LANGUAGE RULES with a MAXIMUM of 4 to 6 text lines in total.


Step to handle EndUser Question that lack clarity or vague/broad questions:
1. Understand the EndUser Question and the intent of the EndUser Question (Read user_intent, topic_focus)
2. Check if the question is clear enough (Read secondary supplemental inputs such as clarity_of_end_user_question, feedback_on_end_user_question)
2. Understand secondary supplemental inputs (feedback_on_end_user_question, router_reasoning_log)
3. Understand the list of topics in the wiki context.
4. If the user's question is framed as broad and generic question, and doesn't include any specific information, answer the generic question with a disclaimer that the question is broad, and say you can provide a more appropriate answer if you know the specific context, and provide suggestions on how to frame effective specific question to help the illitrate enduser.
5. Provide clear holistic answers to the user's question to give unambigious answer. Refer feedback_on_end_user_question and  router_reasoning_log. For example, include the context about when the answer is valid. For example, if you suggest a tablet dosage, state when the answer is valid such Take x amount of tablet, if you have this health condition.
6. Minimize communication gap by sharing the assumptions made about the user's question. In case any assumptions are made while infering the user question, add the assumption made about the user's question. Assumptions can be deduced from the clarity_of_end_user_question, feedback_on_end_user_question and router_reasoning_log.
7. Always adhere to GROUNDING RULES.
8. While answering a question especially unclear questions (refer clarity_of_end_user_question), share any assumptions you make. Use the router_reasoning_log to state any assumptions you made about user intent,  especially when the question is not clear enough or not comprehensive enough (Refer clarity_of_end_user_question).
9. If there are multiple questions or multiple topics, try to answer every question



Steps incase the question can't be answered:
Here are three situations when the question can't be answered:
1. When the Enduser Question lacks clarity (Refer clarity_of_end_user_question and feedback_on_end_user_question)
2. When the input Context is empty (If  'count of the number of topics in the supplied Wiki Context' == 0 ), the question is most likely out of scope of Wiki knowledge.
3. When the Wiki doesn't have the answer, so a grounded answer can't be found.
When answer is not found:
1. Politely respond by outputting : "Mere paas iska uttar nahin hai. Kripya apne najdik ke health facility/doctor/officer se sampark karein. [The Wiki doesn't have any answers to this question]"
2. Add reasons why the answer cannot be found by reading router_reasoning_log and clarity_of_end_user_question
3. Add suggestions for framing a clear question by reading router_reasoning_log and feedback_on_end_user_question.


EXPECTED OUTPUT STYLE AND LANGUAGE RULES:
1. LANGUAGE-MATCHING PARSING MANDATE:
   - If the user query is written in Hindi (Devanagari script), you MUST strictly respond entirely in Hindi using the Devanagari script.
   - If the user query is written in Romanized Hindi (Hinglish/English script with transliterated Hindi words, e.g., 'khana', 'bacha', 'dard'), you MUST strictly respond entirely in Romanized Hindi.
   - If the user query is asked in English, you MUST strictly respond entirely in Romanized Hindi (Hinglish).

2. ABSOLUTE CONTEXTUAL GATEKEEPER LOCK:
    Provide 100% grounded answers by extracting answers from the provided Context (the fact-checked ground-truth Wiki content) .
    You are STRICTLY FORBIDDEN from responding from the Internet.
    You are STRICTLY FORBIDDEN from guessing the answer. Follow the GROUNDING RULES strictly.
    If the answer cannot be found inside the provided Context, you MUST politely communicate that the Wiki doesn't have the answer ('Mere paas iska uttar nahin hai') and why the answer cannot be found. Refer 'Steps incase the question can't be answered'.


3. BRIEF CONVERSATIONAL SHORT-CIRCUITS:
   If the query consists only of emojis, generic greetings, or acknowledgment words (like 'yes', 'thank you', 'ok', 'ji', 'G', 'hi', 'bye', 'theek hai'), respond back briefly and warmly in the same language alignment matching their greeting message.

EXPECTED OUTPUT LENGHT:
Your response must be comprehensive, yet highly concise—restricted to a MAXIMUM of 4 to 5 text lines in total.

Format numbers and core milestones cleanly using scannable bullet characters, keeping the text extremely short and compact for low-bandwidth mobile viewports."""



print("✅ [System Migration Complete]: Step 3 Synthesis prompt locked to SNEHA DIDI production style.")
# Out:
# ✅ [System Migration Complete]: Step 3 Synthesis prompt locked to SNEHA DIDI production style.

# %%
# --- STAGE 3 QA SYNTHESIS   INSTRUCTIONS





TEMPLATE_SYNTHESIS = """
Your goal is to answer the Incoming EndUser Question by extracting answer from the provided Context

Your inputs:
1. Incoming EndUser Query (EndUser's Question) and Extracted entities from the EndUser Question.
     Incoming End User Question: "{user_whatsapp_query}"
     user_intent: "{user_intent}"
     topic_focus: "{topic_focus}"
     extracted_intent_tags: "{extracted_intent_tags}"
     clarity_of_end_user_question: "{clarity_of_end_user_question}"
     feedback_on_end_user_question: "{feedback_on_end_user_question}"
     router_reasoning_log: "{router_reasoning_log}"
     assumptions_made_about_user : "{assumptions_made_about_user}"

2. Here is list of files in the Wiki Folder:
    The count on the number of files in the supplied Wiki Context, count_of_topics_in_context: {howmany}
    list_of_topics_in_context: {listoffilenames}

3. The context to answer from: The ground-truth wiki context blocks organized by topics (You are given seperate Wiki File for each topic)

      You are given {howmany} Wiki Content files.
      The contents of these {howmany} files are presented below one after another, in the same sequence.
      These {howmany} Wiki files are as presented in the following sequence.

      The {howmany} Wiki Files are organized by topics as per the following sequence:
      Table of Contents of Files:
      {tableofcontentoffiles}

      Below are {howmany} markdown files.

      Wiki Content to extract the answer from:
      ==================================================
      === GROUND-TRUTH Wiki Files ===
      {packaged_context_string_payload}
      ==================================================


"""

# %%
def execute_downstream_qa_synthesis(
    openai_client_instance,
    wiki_dir: str,
    user_query: str,
    routing_payload_dict: dict,
    target_gpt_model: str = "gpt-4o-mini"
) -> str:
    """
    Reads selected files from disk, appends context, and generates a context-bounded answer.
    Dynamically adjusts API arguments to accommodate differences between gpt-4o-mini and gpt-5.6-terra.
    """
    # STEP A: The Short-Circuit Guard Checklist Check
    target_slugs = routing_payload_dict.get("target_topic_slugs", [])

   # print("DEBUG router output")
   # print(routing_payload_dict)
   # print("DEBUG router output")

    #if not target_slugs:
     #   print("⏭️  [Pipeline Short-Circuit]: Router returned zero topic matches. Aborting Stage 3 execution.")
      #  return "I am sorry, but that query falls completely outside the scope of our authoritative field manual guidelines."

    # =================================================================
    # load the selected files (these files were shortlisted by router in stage 1 )
    # =================================================================
    print(f"[Stage 2 Injector] 📁 Router selected {len(target_slugs)} targets. Loading files from disk...")
    packaged_context_chunks = []

    print('DEBUG List of Identified files')
    print(target_slugs)
    print('DEBUG End of list of Identified files')

    blocknumber = 0
    tableofcontentoffiles = ""

    for filename in target_slugs:
        blocknumber = blocknumber + 1
        clean_name = filename.strip()
        full_file_path = os.path.join(wiki_dir, clean_name)

        if not os.path.exists(full_file_path):
            print(f"    ⚠️  Warning: Router referenced file '{clean_name}', but it is missing from disk path '{wiki_dir}'. Skipping.")
            continue

        # Open file and read
        with open(full_file_path, 'r', encoding='utf-8') as f_in:
            raw_file_text = f_in.read()

        tableofcontentoffiles = tableofcontentoffiles + f" {blocknumber}: {clean_name}\n"
        # Structure the chunk part inside explicit visual code containment boundaries
        bounded_chunk_part = (
            f"--------------------------------------------------\n"
            f"<Wiki_Context_Block > \n"
            f" File Number {blocknumber} : Unique Wiki Filename: {clean_name} \n"
            f"--- START COMPILED CONTEXT NODE: {clean_name} ---\n"
            f"{raw_file_text}\n"
            f"--- END COMPILED CONTEXT NODE: {clean_name} ---\n"
            f"</Wiki_Context_Block> \n"
            f"--------------------------------------------------\n"
        )
        packaged_context_chunks.append(bounded_chunk_part)

    # Unify all selected file text segments into a single context payload block
    unified_context_string = "\n".join(packaged_context_chunks)
    print(f"[Stage 2 Injector] ✅ Context payload compiled. Total text size: {len(unified_context_string)} characters.")

    # =================================================================
    # STAGE 3: THE GPT content SYNTHESIS - send context files to gpt
    # =================================================================
    print(f"[Stage 3 Synthesis] 🧠 Dispatching context-locked completion via {target_gpt_model}...")

    # Template the unified context string straight into the user prompt payload
    user_prompt_string = TEMPLATE_SYNTHESIS.format(
        packaged_context_string_payload=unified_context_string,
        user_whatsapp_query=user_query,
        howmany=len(target_slugs),
        listoffilenames=target_slugs,
        user_intent = routing_payload_dict.get("user_intent", []),
        topic_focus = routing_payload_dict.get("topic_focus", []),
        extracted_intent_tags = routing_payload_dict.get("extracted_intent_tags", []),
        clarity_of_end_user_question = routing_payload_dict.get("clarity_of_end_user_question", []),
        assumptions_made_about_user = routing_payload_dict.get("assumptions_made_about_user", []),
        feedback_on_end_user_question = routing_payload_dict.get("feedback_on_end_user_question", []),
        router_reasoning_log = routing_payload_dict.get("router_reasoning_log", []),
        tableofcontentoffiles = tableofcontentoffiles,

    )

    # Determine system role: GPT-5 tier requires 'developer' role for systemic instructions
    system_role = "developer" if "gpt-5.6" in target_gpt_model else "system"

    messages_payload = [
        {"role": system_role, "content": SYSTEM_INSTRUCTION_SYNTHESIS},
        {"role": "user", "content": user_prompt_string}
    ]

    # Dynamically assemble the parameter keywords dict
    api_kwargs = {
        "model": target_gpt_model,
        "messages": messages_payload,
        "seed": 42,
        "temperature": 0 # Default to 0 for deterministic output
    }

    # Apply thinking effort exclusively to the GPT-5.6 reasoning flag tracking
    if "gpt-5" in target_gpt_model:
        api_kwargs["reasoning_effort"] = "medium"
        # Remove temperature for GPT-5.6 models if not supported
        if "temperature" in api_kwargs:
            del api_kwargs["temperature"]



    # Call the completions API
    response = openai_client_instance.chat.completions.create(**api_kwargs)

    if not response.choices:
        raise ValueError("❌ Stage 3 Synthesis Fault: OpenAI returned an empty choices list array block.")

    final_conversational_answer = response.choices[0].message.content.strip()
    print("[Stage 3 Synthesis] ✅ Airtight response generated successfully.")
    return final_conversational_answer

# %%
# =====================================================================
#  END-TO-END PIPELINE testing here
# =====================================================================

# Ensure WIKI_VAULT_DIR matches your local environment variable path precisely
# This folder must contain index_detailed.md and your compiled topic pages
WIKI_VAULT_DIR = "/content/LLM_Wiki_Vault/wiki/"

# Define a high-stakes test query
TEST_USER_QUERY = "I am   pregnant. give me all possible advice"

    # Run Step 1: The   Router
routing_payload = execute_gpt_precision_router_with_retry(
        openai_client_instance=openai_client,
        wiki_dir=WIKI_VAULT_DIR,
        user_query=TEST_USER_QUERY
    )


    # Run Step 2 & Load file and
    #        Step 3 QA Synthesis
chatbot_final_answer = execute_downstream_qa_synthesis(
        openai_client_instance=openai_client,
        wiki_dir=WIKI_VAULT_DIR,
        user_query=TEST_USER_QUERY,
        routing_payload_dict=routing_payload
    )

print("\n📱 ===================== WHATSAPP CHATBOT TEXT OUTPUT =====================")
print(chatbot_final_answer)
# Out:
# [Stage 1 Router] ⭁ Ingesting input query: 'I am   pregnant. give me all possible advice' using model 'gpt-4o-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 2 targets. Loading files from disk...
# DEBUG List of Identified files
# ['pregnancy_care_and_checkups.md', 'pregnancy_nutrition_and_diet.md']
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 66377 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-4o-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
#
# 📱 ===================== WHATSAPP CHATBOT TEXT OUTPUT =====================
# Mujhe aapki pregnancy ke liye kuch zaroori salah deni hai:
#
# 1. **Antenatal Check-ups**: Pehli check-up 12 hafte ke andar karein. Kam se kam 4 check-ups zaroori hain.
# 2. **Nutrition**: Rozana 350 extra calories lein, aur iron-folic acid (IFA) tablets lein. Calcium bhi zaroori hai.
# 3. **Danger Signs**: Agar aapko severe headache, bleeding, ya baby ki movement kam mehsoos ho, turant doctor se sampark karein.
# 4. **Hygiene**: Haath dhona, khana achhe se pakana, aur junk food se bachna zaroori hai.
#
# Agar aapko specific advice chahiye, toh aap aur detail mein pooch sakti hain.

# %%
TARGET_LLM_MODEL = "gpt-4o-mini"

# %%
 # 📱   GLIFFIC CHATBOT   INTERFACE
# =====================================================================



def get_chatbot_response(user_question: str) -> str:
    """
    Unified entry point for the downstream WhatsApp Chatbot pipeline.

    Input Parameter:
        user_question (str): The raw text message question received from the user.

    Output Return:
        str: The context-locked, sanitised, and cited answer text block.
    """
    # Assumes WIKI_VAULT_DIR and openai_client have been successfully
    WIKI_VAULT_DIR = "/content/LLM_Wiki_Vault/wiki/"

    try:
        # 1. Trigger Stage 1: The Precision Router with built-in Pydantic Self-Healing retry cascades
        routing_payload = execute_gpt_precision_router_with_retry(
            openai_client_instance=openai_client,
            wiki_dir=WIKI_VAULT_DIR,
            user_query=user_question,
            target_gpt_model=TARGET_LLM_MODEL,
            max_healing_retries=3
        )

        # 2. Trigger Stage 2 & Stage 3: Local Context Ingestion and Ground-Truth QA Synthesis Engine
        final_answer_payload = execute_downstream_qa_synthesis(
            openai_client_instance=openai_client,
            wiki_dir=WIKI_VAULT_DIR,
            user_query=user_question,
            routing_payload_dict=routing_payload,
            target_gpt_model=TARGET_LLM_MODEL
        )

        # Return the pure, conversational string text block directly back to your interface router wrapper
        return final_answer_payload , routing_payload

    except Exception as runtime_pipeline_fault:
        # Operational System Catch Gate: Log error context inside your terminal execution log lines
        print(f"🚨 [Pipeline Fatal Anomaly]: Execution failed. Reason: {str(runtime_pipeline_fault)}")

        # Return a safe, defensive fallback error message token back to the WhatsApp platform queue
        return None, None

# %%
# Execute a live query turn and print the text string output directly
TARGET_LLM_MODEL = "gpt-5.6-luna" # "gpt-4o-mini", "gpt-5.4-mini",  "gpt-5.6-luna"

print(get_chatbot_response("  is to good to feed baby in sleeping ?"))
# Out:
# [Stage 1 Router] ⭁ Ingesting input query: '  is to good to feed baby in sleeping ?' using model 'gpt-5.6-luna'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 2 targets. Loading files from disk...
# DEBUG List of Identified files
# ['breastfeeding_guidance.md', 'general_child_care_and_development.md']
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 60373 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.6-luna...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# ('- Agar breastfeeding ke dauran baby ko neend aa jaye aur woh khud breast chhod de, yeh pet bharne ka sanket ho sakta hai.  \n- Side-lying position mein feed kar sakti hain, par baby ki naak saaf rahe aur saans aasani se aaye.  \n- Feed ke baad baby ko peeth ke bal sulaayen; baby ko poori tarah sote hue akela feed na karayen.  \n- Baby ki umar aur feeding ka tareeka (breast/bottle) batayen, taaki main sahi salah de sakun.', {'router_reasoning_log': "STAGE 0: Translated query: 'Is it good to feed a baby while the baby is sleeping?' User intent is safety and practical guidance about feeding during sleep. Topic focus includes breastfeeding or infant feeding, feeding position, and safe sleep. STAGE 1: Because the feeding method and age are unspecified, the query is treated as a multiple-topic infant-care inquiry. Relevant protocol lanes are breastfeeding guidance and general child care/sleep safety. STAGE 2: Keyword and semantic matching shortlist: breastfeeding_guidance.md for feeding practices, positioning, feeding frequency, and adequacy; general_child_care_and_development.md for infant care and safe sleep. Complementary-feeding guidance may be relevant if the user means solid foods, but this is not explicit.", 'user_intent': ['feeding safety guidance', 'breastfeeding how-to guidance', 'multiple_topics'], 'topic_focus': ['infant feeding', 'breastfeeding guidance', 'feeding position', 'safe sleep'], 'target_topic_slugs': ['breastfeeding_guidance.md', 'general_child_care_and_development.md'], 'extracted_intent_tags': ['baby', 'feeding', 'sleeping', 'breastfeeding', 'safety', 'feedingposition'], 'feedback_on_end_user_question': ["Please specify the baby's age and feeding method for a more accurate answer. Example: 'My 2-month-old baby falls asleep while breastfeeding. Should I wake the baby for feeds, and what is the safest position?'"], 'clarity_of_end_user_question': ["The core concern is understandable, but the question lacks the baby's age, feeding method, and whether the baby is fully asleep or being fed in a side-lying position."], 'assumptions_made_about_user': ['The user is asking whether feeding a baby while the baby is asleep is safe or appropriate.', 'The type of feeding is not specified; it may refer to breastfeeding, bottle-feeding, or complementary foods.', "The baby's age and health status are unknown."]})

# %%
myanswer = get_chatbot_response("  what to feed 3 month child")
print(myanswer)
# Out:
# [Stage 1 Router] ⭁ Ingesting input query: '  what to feed 3 month child' using model 'gpt-5.6-luna'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 2 targets. Loading files from disk...
# DEBUG List of Identified files
# ['breastfeeding_guidance.md', 'complementary_feeding_6_to_24_months.md']
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 73802 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.6-luna...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# ('• 3 mahine ke bachche ko **sirf maa ka doodh** dein—paani, ghutti ya koi solid/anya khana nahi.  \n• Bachche ke bhookh ke sanket par din-raat, aam taur par **24 ghante mein 8–12 baar** doodh pilayein.  \n• 6 mahine poore hone ke baad hi mashed/semi-solid khana shuru karein; breastfeeding jaari rakhein.  \n• Yeh salah swasth, poore samay janme bachche ke liye hai. Kya bachcha breastfed hai ya feeding mein koi dikkat hai?', {'router_reasoning_log': 'STAGE 0: Translated query: "What should I feed a 3-month-old child?" User intent is routine infant feeding, with breastfeeding as the most age-appropriate focus. At 3 months, complementary foods are not the primary feeding topic, but the complementary-feeding file may clarify that solids generally begin at 6 months. STAGE 1: The query aligns primarily with the breastfeeding guidance lane; it does not indicate breastfeeding complications or a growth problem. STAGE 2: Keywords match infant feeding, exclusive breastfeeding, and what to feed a baby; shortlist breastfeeding guidance and the complementary-feeding reference for age-related introduction of solids.', 'user_intent': ['breastfeeding', 'child_feeding'], 'topic_focus': ['infant_feeding', 'exclusive_breastfeeding', 'solids_introduction'], 'target_topic_slugs': ['breastfeeding_guidance.md', 'complementary_feeding_6_to_24_months.md'], 'extracted_intent_tags': ['child', 'infant', '3months', 'feeding', 'breastfeeding', 'exclusivebreastfeeding', 'whattofeed'], 'feedback_on_end_user_question': ['Please specify whether the baby is breastfed or formula-fed and whether there are any feeding problems.', 'Example: "My baby is 3 months old and breastfed. Is breast milk enough, and how often should I feed the baby?"'], 'clarity_of_end_user_question': ["The child's age and general feeding intent are clear.", 'It is unclear whether the child is breastfed, formula-fed, or has a medical condition affecting feeding.', 'More details about current feeding method and any feeding problems would support a more tailored answer.'], 'assumptions_made_about_user': ['The child is approximately 3 months old.', 'The user is asking about routine infant feeding, not treatment for illness or poor weight gain.', 'No breastfeeding difficulty, formula-feeding issue, or medical condition was mentioned.']})

# %% [markdown]
# # Scoring for cosine similarity / LLM judge

# %% [markdown]
# # list of questions

# %%
import pandas as pd

# Load the CSV file into a pandas DataFrame
df_qna = pd.read_csv('/content/adapted prompt_scores.csv')

# Display the first 5 rows to understand the structure

# %%
df_qna.dropna(how='all', inplace=True)
df_qna.dropna(subset=['question'], inplace=True)
df_qna = df_qna[df_qna['question'].str.strip() != '']

print("Empty and NaN rows removed from 'question' column in df_qna.")
# Out:
# Empty and NaN rows removed from 'question' column in df_qna.

# %%
len(df_qna)
# Out:
# 22

# %%
df_qna.head(1)
# Out:
#        Date                             question  \
# 0  7/1/2026  8 month ke baby ko injection lagega
#
#                                           llm_answer User Question - Text  \
# 0  8 mahine ke baby ko kuch injections lagte hain...        User Qs clear
#
#           LLM Response Question Answer Compatibility       Themes   \
# 0  Inaccurate response     Gave inappropriate answer  Immunization
#
#                                        golden_answer  \
# 0  BCG: up to one year of age**   \n**OPV: up to ...
#
#                                            Remarks\n
# 0  Incorrect vaccination schedule. The LLM incorr...

# %%
len(df_qna)
# Out:
# 22

# %%
pausehere
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_57602/612422577.py in <cell line: 0>()
# ----> 1 pausehere
#
# NameError: name 'pausehere' is not defined

# %%
df_qna = df_qna.rename(columns={'llm_answer': 'RAG_answer_PassTru', 'cosine_similarity': 'RAG_cosine_simiarity_PassTru'})

# %%
df_qna.head(1)
# Out:
#        Date                             question  \
# 0  7/1/2026  8 month ke baby ko injection lagega
#
#                                   RAG_answer_PassTru User Question - Text  \
# 0  8 mahine ke baby ko kuch injections lagte hain...        User Qs clear
#
#           LLM Response Question Answer Compatibility       Themes   \
# 0  Inaccurate response     Gave inappropriate answer  Immunization
#
#                                        golden_answer  \
# 0  BCG: up to one year of age**   \n**OPV: up to ...
#
#                                            Remarks\n
# 0  Incorrect vaccination schedule. The LLM incorr...

# %%
columns_to_drop = [col for col in df_qna.columns if col.startswith('Unnamed:')]
df_qna = df_qna.drop(columns=columns_to_drop)

#df_qna = df_qna[['question_id', 'question', 'golden_answer']]

display(df_qna.head(1))
# Out:
#        Date                             question  \
# 0  7/1/2026  8 month ke baby ko injection lagega
#
#                                   RAG_answer_PassTru User Question - Text  \
# 0  8 mahine ke baby ko kuch injections lagte hain...        User Qs clear
#
#           LLM Response Question Answer Compatibility       Themes   \
# 0  Inaccurate response     Gave inappropriate answer  Immunization
#
#                                        golden_answer  \
# 0  BCG: up to one year of age**   \n**OPV: up to ...
#
#                                            Remarks\n
# 0  Incorrect vaccination schedule. The LLM incorr...

# %%
import time

# %%
for i in range(len(df_qna)):
    question = df_qna.loc[i, 'question']
    #print(i)
    # print(question)

# %%
df_qna = df_qna2.copy()

# %%
df_qna.head(1)
# Out:
#        Date                             question  \
# 0  7/1/2026  8 month ke baby ko injection lagega
#
#                                   RAG_answer_PassTru User Question - Text  \
# 0  8 mahine ke baby ko kuch injections lagte hain...        User Qs clear
#
#           LLM Response Question Answer Compatibility       Themes   \
# 0  Inaccurate response     Gave inappropriate answer  Immunization
#
#                                        golden_answer  \
# 0  BCG: up to one year of age**   \n**OPV: up to ...
#
#                                            Remarks\n  \
# 0  Incorrect vaccination schedule. The LLM incorr...
#
#                            llm_wiki_answer_gpt4omini  ...  \
# 0  Aapka 8 mahine ke bache ko kuch injections lag...  ...
#
#   cosine_similarity_wiki_gpt4omini  llm_judge_score_wiki_gpt4omini  \
# 0                            0.489                             4.0
#
#                   llm_judge_reasoning_wiki_gpt4omini  \
# 0  Safety: 5.0, Clarity: 4.5, Completeness: 3.5, ...
#
#                            llm_wiki_answer_gpt54mini  \
# 0  • Agar aap 8 month ke baby ke routine vaccine ...
#
#                              wiki_thinking_gpt54mini  \
# 0  {'router_reasoning_log': "STAGE 0: Translated ...
#
#                            llm_wiki_answer_gpt56luna  \
# 0  8 mahine par routine schedule mein alag inject...
#
#                              wiki_thinking_gpt56luna  \
# 0  {'router_reasoning_log': 'STAGE 0: Translated ...
#
#   cosine_similarity_wiki_gpt56luna  llm_judge_score_wiki_gpt56luna  \
# 0                            0.602                             4.5
#
#                   llm_judge_reasoning_wiki_gpt56luna
# 0  Safety: 5.0, Clarity: 4.0, Completeness: 4.5, ...
#
# [1 rows x 21 columns]

# %%
MAX_RETRIES = 3
TARGET_LLM_MODEL = "gpt-5.4-mini"
EXP_NUMBER = '_gpt54mini'

#TARGET_LLM_MODEL = "gpt-5.6-luna" # "gpt-4o-mini", "gpt-5.4-mini",  "gpt-5.6-luna"


df_qna['llm_wiki_answer' + EXP_NUMBER] = ''
df_qna['wiki_thinking' + EXP_NUMBER] = ''



for i in range(len(df_qna)):
    question = df_qna.loc[i, 'question']
    print(f"\nProcessing question {i+1}: '{question}'")

    attempt = 0
    while attempt < MAX_RETRIES:
        try:
            answer, thoughtprocess = get_chatbot_response(question)

            if answer is None:
                print(f"    ⚠️ Attempt {attempt + 1}/{MAX_RETRIES}: get_chatbot_response returned None for question '{question}'. Retrying...")
                attempt += 1
                time.sleep(2) # Wait a bit before retrying
                continue
            else:
                df_qna.loc[i, 'llm_wiki_answer' + EXP_NUMBER] = answer
                df_qna.loc[i, 'wiki_thinking'  + EXP_NUMBER] = str(thoughtprocess)

                print(f"--------------------")
                print(f"--------ANSWER------")
                print(f" {answer}")
                print(f"--------------------")

                print(f"--------ROUTER THOUGHT PROCESS------")
                print(f"LLM Wiki Thinking: {thoughtprocess}")
                print(f"===================================================")
                print(f"***************************************************")
                break # Exit retry loop on success

        except Exception as e:
            print(f"    ❌ Attempt {attempt + 1}/{MAX_RETRIES}: An exception occurred for question '{question}': {e}. Retrying...")
            attempt += 1
            time.sleep(2) # Wait a bit before retrying

    else:
        # This block executes if the while loop completes without a 'break'
        print(f"    🚨 Failed to process question '{question}' after {MAX_RETRIES} attempts. Skipping.")
        df_qna.loc[i, 'llm_wiki_answer' + EXP_NUMBER] = "Error: Failed after multiple retries."
        df_qna.loc[i, 'wiki_thinking'  + EXP_NUMBER] = "Error: Failed after multiple retries."



display(df_qna.head(1))
# Out:
# Processing question 1: '8 month ke baby ko injection lagega'
#
# [Stage 1 Router] ⭁ Ingesting input query: '8 month ke baby ko injection lagega' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 1 targets. Loading files from disk...
# DEBUG List of Identified files
# ['immunization_schedule_and_basics.md']
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 38441 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  • Is NIS schedule ke hisaab se 8 month ke baby ke liye yahan koi routine injection/vaccine listed nahin hai.
# • Agla routine dose 9 completed months–12 months par hota hai: Measles/MR, JE (sirf endemic districts me), aur Vitamin A ka 1st dose.
# • Is document me missed/delay doses ya catch-up schedule ka uttar nahin diya gaya hai.
# • Agar previous vaccines time par nahi lage hain, to exact schedule ke liye vaccination history batayein ya doctor/health facility se poochhein.
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': 'STAGE 0: Translated query from Hinglish to English: "Will an 8-month-old baby need an injection/vaccine?" User intent = immunization; topic focus = schedule_basics. Assumptions: the user is asking about the routine vaccine due at this age, not about side effects or missed doses. STAGE 1: Matched against SECTION_1_ROUTING_DIRECTIVES -> user_intent_profile = immunization and topic_focus = schedule_basics, which maps to ISOLATE_IMMUNIZATION_SCHEDULE_LANE. STAGE 2: Cross-referenced keywords (8 month, baby, injection, vaccine) against SECTION_2_INCLUSION_KEYWORDS -> strongest filename match is immunization_schedule_and_basics.md. No additional files are required because the question is not about vaccine reactions or catch-up exceptions.', 'user_intent': ['immunization'], 'topic_focus': ['schedule_basics'], 'target_topic_slugs': ['immunization_schedule_and_basics.md'], 'extracted_intent_tags': ['8 month', 'baby', 'injection', 'vaccine', 'immunization', 'schedule'], 'feedback_on_end_user_question': ['You can ask more specifically: "My baby is 8 months old. Which vaccines are due now, and what was the schedule if previous vaccines were delayed?" This helps identify the exact immunization guidance needed.'], 'clarity_of_end_user_question': ['Mostly clear for routing, but it does not mention whether the baby has received previous vaccines on time. If you want a more exact answer, include the vaccination history.'], 'assumptions_made_about_user': ['Assumed the user is asking about a routine vaccine due for an 8-month-old baby.', 'Assumed there is no urgent vaccine reaction or fever concern mentioned in the query.']}
# ===================================================
# ***************************************************
#
# Processing question 2: 'Bol ke bhejo mujhe nahin samajh mein a raha hai'
#
# [Stage 1 Router] ⭁ Ingesting input query: 'Bol ke bhejo mujhe nahin samajh mein a raha hai' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 0 targets. Loading files from disk...
# DEBUG List of Identified files
# []
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 0 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  Mere paas iska uttar nahin hai. Kripya apne najdik ke health facility/doctor/officer se sampark karein. [Wiki me is sawal ka jawab nahi hai]
# Aapka sawal clear nahi tha, isliye sahi topic decide nahi ho paya.
# Kripya seedha likhiye: “kisko problem hai, kya symptom hai, kitne din se hai?”
# Jaise: “Mera bachcha 3 din se bukhar me hai, kya karun?”
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': 'STAGE 0: Hindi/Hinglish to English translation -> "Please say/send it to me; I am not समझ पा रहा हूँ / I don\'t understand." User intent appears to be a clarification request, not a health-topic question. Topic focus cannot be determined from the text. Assumptions made: user may be asking for a simpler explanation or voice-style response about a previous topic, but no subject is provided.\nSTAGE 1: SECTION_1_ROUTING_DIRECTIVES match check -> no applicable health routing directive because there is no identifiable topic such as pregnancy, child care, immunization, breastfeeding, schemes, or services.\nSTAGE 2: SECTION_2_INCLUSION_KEYWORDS check -> no keyword overlap with any gated health document. No valid filename candidates found. Out of scope / insufficiently specific for routing.', 'user_intent': ['general_unclassified_inquiry'], 'topic_focus': ['unclear_clarification_request'], 'target_topic_slugs': [], 'extracted_intent_tags': ['bol', 'bhejo', 'samajh', 'nahin', 'a', 'raha'], 'feedback_on_end_user_question': ['Kripya apna health question thoda clearly likhiye. Example: "Mera bachcha 3 din se bukhar me hai, kya karun?" ya "Pregnancy ke 2nd trimester me kya khana chahiye?" Specific topic, age/stage, aur symptoms likhen to sahi jawab mil sakega.'], 'clarity_of_end_user_question': ['Not clear and not comprehensive enough to route to a health knowledge file.'], 'assumptions_made_about_user': ['User likely wants a simpler explanation or a more conversational/voice-style response, but no actual medical or public-health topic was provided.']}
# ===================================================
# ***************************************************
#
# Processing question 3: '5 months pregnancy may baby ka weight kitna Rehta Hai'
#
# [Stage 1 Router] ⭁ Ingesting input query: '5 months pregnancy may baby ka weight kitna Rehta Hai' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 2 targets. Loading files from disk...
# DEBUG List of Identified files
# ['pregnancy_care_and_checkups.md', 'pregnancy_nutrition_and_diet.md']
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 66377 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  Mere paas 5 months pregnancy me baby ke exact weight ka uttar nahin hai.
# Is wiki me sirf itna hai ki 18–22 weeks par anomaly scan hota hai, aur 28–32 weeks par baby ki growth dekhi jaati hai.
# Baby ka exact weight ultrasound/report ke gestational age aur fetal weight likhe hone par hi bataya ja sakta hai.
# Aap aise pooch sakti hain: “Main 20 weeks pregnant hoon, ultrasound me baby ka weight kitna hona chahiye?”
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': "STAGE 0: Translated Hinglish query to English as: 'At 5 months of pregnancy, what is the baby's weight?' Intent inferred as pregnancy_care; topic is fetal growth/overall pregnancy information. STAGE 1: No specific diet, anemia, or checkup-test request; closest routing is pregnancy general overview. STAGE 2: Inclusion keyword overlap is pregnancy + weight/growth-adjacent terms; shortlist the pregnancy overview files, with checkup and nutrition documents as the safest pool.", 'user_intent': ['pregnancy_care'], 'topic_focus': ['general_overview'], 'target_topic_slugs': ['pregnancy_care_and_checkups.md', 'pregnancy_nutrition_and_diet.md'], 'extracted_intent_tags': ['5', 'months', 'pregnancy', 'baby', 'weight', 'kitna'], 'feedback_on_end_user_question': ["Aap agar 5 months pregnancy me baby ke average weight ke baare me pooch rahe hain, to aur specific likhiye: 'Main 20 weeks pregnant hoon. Baby ka average weight kitna hota hai?' Agar ultrasound report samajhni hai, to report me likha gestational age aur fetal weight bhi batayein."], 'clarity_of_end_user_question': ['Question clear hai, lekin answer exact gestational age (weeks) aur ultrasound/report context par depend karta hai.'], 'assumptions_made_about_user': ["Assumed '5 months pregnancy' means around 20 weeks gestation.", "Assumed 'baby ka weight' refers to fetal weight, not mother's weight.", 'Assumed singleton pregnancy unless stated otherwise.']}
# ===================================================
# ***************************************************
#
# Processing question 4: 'Nava lagne wala hai nava lagne mein 10 din Abhi baki hai'
#
# [Stage 1 Router] ⭁ Ingesting input query: 'Nava lagne wala hai nava lagne mein 10 din Abhi baki hai' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 2 targets. Loading files from disk...
# DEBUG List of Identified files
# ['pregnancy_care_and_checkups.md', 'childbirth_and_newborn_care.md']
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 66807 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  • Main maan kar chal rahi hoon ki aapki delivery lagbhag 10 din mein due hai.
# • Abhi birth preparedness karo: supportive companion chuno, delivery bag taiyar rakho, aur emergency ke liye paise/transport set rakho.
# • Bag mein Aadhaar, MCP card, blood reports, ultrasound reports, soap, towel, toothbrush, aur maa-bachche ke kapde rakho.
# • Labor shuru ho ya koi complication ho to turant health centre jao; ambulance 102/108 par milti hai.
# • Agar dard, pani aana, bleeding, ya bacche ki movement kam ho to bina der kiye doctor/health worker se sampark karo.
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': "STAGE 0: Hindi/Hinglish intent translation => 'Delivery is expected soon; 10 days are left.' The user seems to be asking about nearing delivery / birth timing and likely preparation. STAGE 1: Best protocol alignment is pregnancy_care with birth_preparedness, and childbirth_newborn with labor_delivery / imminent delivery context. STAGE 2: Inclusion keyword check matched 'birth preparedness', 'when to go to hospital', 'signs of labor', and general delivery-prep content. Because the query is vague, shortlist is widened to include both relevant files.", 'user_intent': ['pregnancy_care', 'childbirth_newborn'], 'topic_focus': ['birth_preparedness', 'labor_delivery', 'general_overview'], 'target_topic_slugs': ['pregnancy_care_and_checkups.md', 'childbirth_and_newborn_care.md'], 'extracted_intent_tags': ['nava', 'lagne', '10 din', 'baki', 'delivery', 'due', 'birth_preparedness', 'labor'], 'feedback_on_end_user_question': ["Aap agar delivery ki taiyari pooch rahe hain to aur specific likhen: 'meri delivery 10 din mein due hai, mujhe kya taiyari karni chahiye aur kab hospital jana chahiye?'", 'Agar koi symptom hai to batayein: dard, pani aana, bleeding, ya bacche ki movement kam hai?'], 'clarity_of_end_user_question': ['Partially clear; delivery due soon is understood, but the exact information needed is not stated.'], 'assumptions_made_about_user': ['User is pregnant and due for delivery in about 10 days.', 'The query is about delivery preparation or imminent labor guidance.']}
# ===================================================
# ***************************************************
#
# Processing question 5: 'Chhota baby baten kab shuru karte Hain'
#
# [Stage 1 Router] ⭁ Ingesting input query: 'Chhota baby baten kab shuru karte Hain' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 1 targets. Loading files from disk...
# DEBUG List of Identified files
# ['general_child_care_and_development.md']
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 26605 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  Is wiki me baby ke **kab bolna shuru karta hai** ki exact umar nahi di gayi hai.
# Haan, **newborn aur chhote bachche se baat karna** unke **learning aur development** me madad karta hai.
# **Assumption:** aap speech/development ke baare me poochh rahi hain.
# Agar bachche ki development ko lekar chinta ho, **health worker se jaldi baat karein**.
# Aap baby ki **age** bata dein to main aur sahi jawab de sakti hoon.
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': "STAGE 0: Translated query from Hinglish to English as: 'When does a small baby start talking?' The likely user intent is a child development milestone question about speech/language onset. Topic focus inferred as developmental support / general child development. Assumptions made: the user is asking about speech development, not feeding or a medical speech disorder. STAGE 1: Mapped the intent to child_care, because the query concerns general child development rather than growth/nutrition/immunization. Among SECTION_1_ROUTING_DIRECTIVES, the closest fit is the child_care general overview lane, since speech milestones are part of developmental support covered by the general child care document. STAGE 2: Cross-referenced keywords like 'talk', 'start speaking', 'development', 'milestone' against SECTION_2_INCLUSION_KEYWORDS. The only applicable file is general_child_care_and_development.md, which includes developmental support and general child-care guidance. No stronger competing file matched.", 'user_intent': ['child_care'], 'topic_focus': ['general_overview'], 'target_topic_slugs': ['general_child_care_and_development.md'], 'extracted_intent_tags': ['baby', 'start', 'talking', 'speech', 'development', 'milestone', 'kab', 'shuru'], 'feedback_on_end_user_question': ["Aap thoda aur specific puchhen to behtar jawab milega, jaise: 'Mera baby 12 mahine ka hai, abhi sirf awaz nikalta hai, bolna kab start karta hai?' ya 'Baby ke bolne me delay ka pata kaise chale?'"], 'clarity_of_end_user_question': ['Slightly unclear due to shorthand spelling, but overall intent is understandable as a baby speech/development milestone question.'], 'assumptions_made_about_user': ['Assumed the user is asking about when a young child starts speaking/talking, not about feeding or a medical emergency. Assumed the concern is general developmental guidance for a baby/infant.']}
# ===================================================
# ***************************************************
#
# Processing question 6: 'Is wakt kya kru ges khatm karne ke liye'
#
# [Stage 1 Router] ⭁ Ingesting input query: 'Is wakt kya kru ges khatm karne ke liye' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 0 targets. Loading files from disk...
# DEBUG List of Identified files
# []
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 0 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  Mere paas iska uttar nahin hai. Kripya apne najdik ke health facility/doctor/officer se sampark karein.
# [Wiki mein gas/flatulence, bloating, acidity ya indigestion par koi topic nahin hai.]
# Maine yeh maana ki aap pet ki gas ki baat kar rahe the, cylinder gas ki nahin.
# Agar aap batayen: dard, ulti, bukhar, kabz, ya pregnancy hai ya nahin — to main behtar madad kar sakti hoon.
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': 'STAGE 0: Translated query from Hinglish to English as: “What should I do right now to get rid of gas?” Interpreted user_intent as a general symptom-relief request for gas/flatulence/bloating. Topic focus does not cleanly map to any defined maternal/child taxonomy in the manifest; possible loose relation to diet/nutrition but no explicit pregnancy/child context is provided.\nSTAGE 1: Checked SECTION_1_ROUTING_DIRECTIVES. No direct directive matches gas/flatulence. The query is not clearly pregnancy, newborn, breastfeeding, child care, immunization, schemes, or local services. Best fit is general_unclassified_inquiry only as a fallback, but the master pool documents do not contain a gas/flatulence topic.\nSTAGE 2: Cross-referenced SECTION_2_INCLUSION_KEYWORDS. No file has gated keywords for gas, bloating, acidity, indigestion, or flatulence. Closest loose thematic overlap is nutrition/diet, but it is not sufficient for a reliable retrieval target. Therefore no exact filename can be confidently shortlisted.', 'user_intent': ['general symptom relief / advice for gas or bloating'], 'topic_focus': ['dietary or digestive discomfort'], 'target_topic_slugs': [], 'extracted_intent_tags': ['gas', 'kya kru', 'khatm karne', 'relief', 'bloating'], 'feedback_on_end_user_question': ['Aap thoda aur specific puchhen to behtar jawab milega. Example: “Mujhe pet me gas aur bloating ho rahi hai, 2 din se. Kya khau aur kya na khau?” Ya agar pregnancy/child ke baare me hai to umar aur stage batayein.'], 'clarity_of_end_user_question': ['Question clear nahi hai: ‘gas’ se aap pet ki gas/bloating, acidity, ya aur kuch mean kar rahe hain, yeh specify nahi hai. Age, pregnancy status, aur symptoms (dard, ulti, bukhar, constipation) bhi nahi diye gaye.'], 'assumptions_made_about_user': ['Assumed user is referring to stomach gas/flatulence rather than cylinder gas.', 'Assumed no pregnancy/child context because it was not mentioned.']}
# ===================================================
# ***************************************************
#
# Processing question 7: 'Dast padhne per kya khayen'
#
# [Stage 1 Router] ⭁ Ingesting input query: 'Dast padhne per kya khayen' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 0 targets. Loading files from disk...
# DEBUG List of Identified files
# []
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 0 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  Mere paas iska uttar nahin hai. Kripya apne najdik ke health facility/doctor/officer se sampark karein. [Wiki me is sawal ka jawab nahin hai]
# Yeh sawal thoda incomplete hai: bachcha ya adult, umar, kitne din se dast, aur bukhar/ulti/khun/dehydration hai ya nahi—yeh batana hoga.
# Agle baar aise pooch sakte hain: “Mere 2 saal ke bachche ko 2 din se dast hain, usko kya khilana chahiye?”
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': "STAGE 0: Translated query from Hindi/Hinglish to English as: 'What should I eat when I have diarrhea/loose motions?' Intent inferred: dietary guidance during illness; topic focus: nutrition/diet plus diarrhea symptom management. User context is missing age, pregnancy status, and whether this is for a child or adult. STAGE 1: No exact routing directive in SECTION_1_ROUTING_DIRECTIVES directly matches diarrhea/loose motions. The query does not clearly fit pregnancy_care, childbirth_newborn, breastfeeding, child_feeding, immunization, govt_schemes, or local_services. Best fallback is general_unclassified_inquiry, but that pool still lacks diarrhea-specific diet guidance. STAGE 2: Cross-reference of keywords ('khayen', 'dast', loose motions) against SECTION_2_INCLUSION_KEYWORDS found no exact file with diarrhea diet instructions. Because no target file can be confidently shortlisted from the manifest, return empty shortlist and request clarification.", 'user_intent': ['dietary guidance during diarrhea/loose motions'], 'topic_focus': ['nutrition_diet', 'diarrhea_symptom_management'], 'target_topic_slugs': [], 'extracted_intent_tags': ['dast', 'khayen', 'diarrhea', 'loose motions', 'eat', 'food', 'diet', 'nutrition'], 'feedback_on_end_user_question': ['Please specify for whom this is: a child or an adult, and mention age if it is a child. Also share how long the diarrhea has been going on, and whether there is fever, vomiting, blood in stool, or signs of dehydration.', "Example of a clearer question: 'Mere 2 saal ke bachche ko 2 din se dast ho rahe hain. Usko kya khilana chahiye aur kya nahi?'"], 'clarity_of_end_user_question': ['partially clear but incomplete'], 'assumptions_made_about_user': ['Assumed the user is asking about diet during loose motions/diarrhea.', 'Assumed no pregnancy or age information was provided, so the question cannot be routed to a specific maternal or child-age document with confidence.']}
# ===================================================
# ***************************************************
#
# Processing question 8: 'Mujhe dard nahi aaa raha hai Dard aaye is ke liye kya karna chahiye'
#
# [Stage 1 Router] ⭁ Ingesting input query: 'Mujhe dard nahi aaa raha hai Dard aaye is ke liye kya karna chahiye' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 2 targets. Loading files from disk...
# DEBUG List of Identified files
# ['childbirth_and_newborn_care.md', 'pregnancy_care_and_checkups.md']
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 66807 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  Mere paas dard ko “start” karne ka nishchit uttar nahin hai; wiki mein labor induce karne ke tareeke diye nahin gaye.
# Assumption: aap pregnant hain aur due date ke paas hain.
# Wiki ke hisaab se labor shuru ho ya koi complication ho to turant healthcare centre se sampark karein, delay na karein.
# Delivery bag, supportive person, emergency paise aur ambulance 102/108 pehle se ready rakhein; bleeding, pani nikalna, bukhar ya baby movement kam ho to turant doctor ko dikhayein.
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': "STAGE 0: Hinglish query translated as 'I am not getting pain; what should I do to make labor pain start?'. Likely user is pregnant and asking about onset of delivery pain; key tokens: dard, pain, labor, delivery. STAGE 1: Best protocol match is childbirth_newborn with topic_focus labor_delivery; secondary possible match is pregnancy_care because the question is vague and may relate to late-pregnancy birth preparedness/danger signs. STAGE 2: Inclusion keywords matched most strongly: labor, delivery, signs of labor, when to go to hospital; secondary pregnancy-related keywords matched: birth preparedness, danger signs in pregnancy.", 'user_intent': ['childbirth_newborn'], 'topic_focus': ['labor_delivery'], 'target_topic_slugs': ['childbirth_and_newborn_care.md', 'pregnancy_care_and_checkups.md'], 'extracted_intent_tags': ['dard', 'pain', 'labor', 'delivery', 'pregnancy', 'term', 'due date'], 'feedback_on_end_user_question': ["Please mention how many weeks pregnant you are or whether your due date has passed, and whether there is any bleeding, पानी निकलना, fever, or baby movement changes. Example: 'I am 39 weeks pregnant, no pain yet, no bleeding, baby is moving normally. What should I do?'"], 'clarity_of_end_user_question': ['Unclear and incomplete: it does not say pregnancy week, due date, or any danger signs, so the exact guidance may depend on whether this is late pregnancy/labor or another type of pain.'], 'assumptions_made_about_user': ['Assuming the user may be pregnant near term and is asking about labor pain not starting.']}
# ===================================================
# ***************************************************
#
# Processing question 9: 'Gla kahe liye jalta hai'
#
# [Stage 1 Router] ⭁ Ingesting input query: 'Gla kahe liye jalta hai' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 0 targets. Loading files from disk...
# DEBUG List of Identified files
# []
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 0 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  Mere paas iska uttar nahin hai. Kripya apne najdik ke health facility/doctor/officer se sampark karein. [The Wiki doesn't have any answers to this question]
# Ye sawal thoda generic hai aur is KB ke scope se bahar lag raha hai; yahan gale ki jalan ke liye koi grounded info nahi hai.
# Agar aap chahen, to yeh likhiye: jalan kab se hai, bukhar/khansi hai ya nahi, acidity hai ya nahi, aur nigalne me dard hai ya nahi.
# Example: “Mere gale me 2 din se jalan hai, bukhar aur khansi nahi hai.”
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': "STAGE 0: User query 'Gla kahe liye jalta hai' transliterates to 'Why does the throat burn?' Intended meaning: symptom/danger-sign style medical question about throat burning, possibly acidity/reflux, infection, or irritation. STAGE 1: Checked SECTION_1_ROUTING_DIRECTIVES; no direct match for general throat-burning symptom under pregnancy, newborn, child care, immunization, government schemes, or local services. STAGE 2: Cross-referenced SECTION_2_INCLUSION_KEYWORDS; no filename contains throat burning, acidity, reflux, cough, or general adult symptom guidance. Result: out of scope for this KB; no safe exact file shortlist.", 'user_intent': ['general_unclassified_inquiry'], 'topic_focus': ['out_of_scope_symptom', 'throat_burning'], 'target_topic_slugs': [], 'extracted_intent_tags': ['gla', 'gala', 'jalta', 'throat', 'burning', 'symptom'], 'feedback_on_end_user_question': ["Ye sawal thoda generic hai aur is KB ke scope se bahar lag raha hai. Agar aap chahte hain ki sahi jawab mile, to kuch details likhiye: gale me jalan kab se hai, bukhar/cough/khansi hai ya nahi, acidity ya khana nigalne me dard hai ya nahi. Example: 'Mere gale me 2 din se jalan hai, bukhar aur khansi nahi hai.'"], 'clarity_of_end_user_question': ['unclear', 'out_of_scope_for_current_kb'], 'assumptions_made_about_user': ["Assumed 'gla' means 'gala' (throat).", 'Assumed the user is asking about a symptom rather than a scheme, pregnancy, child health, or immunization topic.', 'Assumed no additional context was provided about age, duration, fever, cough, or acidity.']}
# ===================================================
# ***************************************************
#
# Processing question 10: 'Meri rat ko soti nhi hai.....'
#
# [Stage 1 Router] ⭁ Ingesting input query: 'Meri rat ko soti nhi hai.....' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 1 targets. Loading files from disk...
# DEBUG List of Identified files
# ['general_child_care_and_development.md']
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 26605 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  Agar aapke bacche ko raat ko neend nahi aa rahi, to umar ke hisaab se neend alag hoti hai: 0–3 mahine 14–17 ghante, 4–11 mahine 12–16 ghante, 1–2 saal 11–14 ghante, aur 2 saal se bade 10–13 ghante.
# Baby ko sulaate waqt peeth ke bal sulaayein; pehle saal me ye safe hai.
# Agar baccha theek se nahi kha raha/pee raha, saans tez hai, bukhar hai, ya bahut kam active hai, to health worker ko jaldi dikhayein.
# Ye jawab general hai; age batayengi to main aur sahi jawab de sakti hoon.
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': "STAGE 0: User query translated from Hinglish/Hindi shorthand to English as: 'My baby/child does not sleep at night.' Primary intent inferred as child sleep concern, with topic focus on general child care and sleep routines. Assumption made: the question is about a baby/young child rather than the user themselves. STAGE 1: Compared against routing directives; best match is user_intent_profile = child_care and topic_focus = general_hygiene_safety_sleep. STAGE 2: Cross-referenced inclusion keywords; matched sleep-related scope in general_child_care_and_development.md (baby sleep, how much should baby sleep, safe sleep). Question is slightly unclear because age and whether this is the user or a child are not specified.", 'user_intent': ['child_care'], 'topic_focus': ['general_hygiene_safety_sleep'], 'target_topic_slugs': ['general_child_care_and_development.md'], 'extracted_intent_tags': ['raat', 'soti', 'nhi', 'sleep', 'baby_sleep', 'child_care'], 'feedback_on_end_user_question': ["Aap thoda aur specific poochhein, jaise: 'Mera 6 mahine ka baby raat ko baar-baar jaagta hai aur so nahi paata. Kya karun?' Age aur symptoms batane se sahi jawab milta hai."], 'clarity_of_end_user_question': ['Partially clear'], 'assumptions_made_about_user': ['Assumed the query is about a baby/young child not sleeping at night, not about the adult user themselves.', 'Assumed this is a general child sleep-care question without emergency danger signs.']}
# ===================================================
# ***************************************************
#
# Processing question 11: 'Abhi kal mai doctor ke paas jaungi cekup ke liye tab mai aap ko report sher karungi ok'
#
# [Stage 1 Router] ⭁ Ingesting input query: 'Abhi kal mai doctor ke paas jaungi cekup ke liye tab mai aap ko report sher karungi ok' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 0 targets. Loading files from disk...
# DEBUG List of Identified files
# []
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 0 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  Theek hai didi, aap kal doctor ke paas jaakar report bhej dijiye.
# Mere paas iska uttar nahin hai. Kripya apne najdik ke health facility/doctor/officer se sampark karein. [Wiki mein is sawal ka jawab nahin hai]
# Yeh sawal abhi clear medical question nahi hai; isme sirf checkup aur report share karne ki baat hai.
# Agle baar bataiye: checkup kis cheez ka hai, aur report se aapko kya samajhna hai.
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': 'STAGE 0: Translated Hinglish query to English: "I will go to the doctor tomorrow for a checkup and then I will share the report with you, okay." Intent appears to be a future update / follow-up, not a medical question. Topic focus is a generic doctor checkup/report sharing request. STAGE 1: No exact match to pregnancy, childbirth/newborn, breastfeeding, child care, immunization, government schemes, or local services directives. STAGE 2: No inclusion keywords strongly match because the user did not ask about any clinical condition, test, pregnancy stage, vaccination, or service directory. Result: no target file can be confidently shortlisted.', 'user_intent': ['follow_up_update', 'generic_checkup_context'], 'topic_focus': ['general_checkup', 'report_sharing'], 'target_topic_slugs': [], 'extracted_intent_tags': ['doctor', 'kal', 'checkup', 'report', 'share'], 'feedback_on_end_user_question': ['Your message does not ask a medical question yet. Please tell me what the checkup is for and what help you need from the report.', 'Example: "Main 6 mahine pregnant hoon. Kal routine checkup hai. Kya tests hote hain aur report kaise samjhun?"'], 'clarity_of_end_user_question': ['Not clear enough to route to a specific health topic.', 'No condition, age/life stage, or specific medical concern is mentioned.'], 'assumptions_made_about_user': ['Assumed the user is planning a routine doctor visit.', 'Did not assume pregnancy, child illness, or any specific diagnosis because the query does not state it.']}
# ===================================================
# ***************************************************
#
# Processing question 12: 'Mai 9 month ki paregnet hu mare hath ki ungli me sujan ari h to ky karu'
#
# [Stage 1 Router] ⭁ Ingesting input query: 'Mai 9 month ki paregnet hu mare hath ki ungli me sujan ari h to ky karu' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 1 targets. Loading files from disk...
# DEBUG List of Identified files
# ['pregnancy_care_and_checkups.md']
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 29694 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  Aap 9 month pregnant hain aur haath/ungli ki sujan **danger sign** ho sakti hai.
# **Turant doctor/healthcare provider se milen** ya nearest health facility par check karayen.
# Agar saath me **tez headache, chakkar, BP high, face/paon ki sujan, bleeding, dard, bukhar, ya baby ki movement kam** ho to jaldi se jaldi dikhayen.
# Assumption: maine maana hai sujan fingers/hand me hai aur aap late pregnancy me hain.
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': "STAGE 0: Translated user query from Hinglish: 'I am 9 months pregnant; my finger/hand is swelling; what should I do?' Intent inferred as pregnancy care with a possible danger sign concern. Topic focus: pregnancy danger signs / antenatal concern. Assumptions: user is currently in late third trimester (9 months) and is asking about edema/swelling in fingers. STAGE 1: Matched against routing directives for pregnancy_care; although 'danger signs in pregnancy' is not a standalone directive, the closest and most appropriate pregnancy care document is the antenatal/check-up protocol lane. STAGE 2: Cross-referenced inclusion keywords; 'danger signs in pregnancy' and related antenatal concern align with pregnancy_care_and_checkups.md. Shortlist finalized to one file.", 'user_intent': ['pregnancy_care'], 'topic_focus': ['danger_signs_in_pregnancy'], 'target_topic_slugs': ['pregnancy_care_and_checkups.md'], 'extracted_intent_tags': ['9', 'month', 'pregnant', 'hand', 'finger', 'sujan', 'swelling', 'what', 'to', 'do'], 'feedback_on_end_user_question': ["Please ask a more specific question, for example: 'I am 9 months pregnant. My fingers/hand are swollen since today. I also have/do not have headache, blurred vision, face swelling, or high BP. What should I do?' This helps identify whether the swelling is a normal pregnancy issue or a danger sign."], 'clarity_of_end_user_question': ['Moderately clear for routing, but incomplete for clinical triage because it does not mention blood pressure, headache, vision changes, face/feet swelling, pain, or sudden onset.'], 'assumptions_made_about_user': ['Assumed the user is 9 months pregnant and the swelling is in the fingers/hand (edema) during late pregnancy.']}
# ===================================================
# ***************************************************
#
# Processing question 13: 'Doctor se chaup karyi hu wajan kam hai aur pani ki kami bata raha gai'
#
# [Stage 1 Router] ⭁ Ingesting input query: 'Doctor se chaup karyi hu wajan kam hai aur pani ki kami bata raha gai' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 3 targets. Loading files from disk...
# DEBUG List of Identified files
# ['child_growth_and_malnutrition.md', 'pregnancy_care_and_checkups.md', 'pregnancy_nutrition_and_diet.md']
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 106739 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  Aapka sawaal thoda unclear hai; main yeh maan kar jawab de rahi hoon ki baat pregnancy ya child ke checkup ki hai.
# • Agar pregnancy hai, to ANC me weight monitoring hoti hai, aur 28–32 weeks ke ultrasound me amniotic fluid level bhi dekha jata hai.
# • Pregnancy me 2 liter se zyada fluids lein, aur IFA aur calcium tablet ek saath na lein.
# • Agar baby/child ka weight kam hai, to wo underweight/malnutrition ka sanket ho sakta hai; LBW baby ka birth weight 2.5 kg se kam hota hai.
# • Agar aap bata dein pregnancy hai ya bachcha, aur age/mahina, to main zyada sahi jawab de dungi.
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': "STAGE 0: Translated query as: 'I got checked by a doctor; weight is low and there is a shortage of water.' User intent is ambiguous health follow-up after checkup; topic focus spans low weight/growth concern and possible fluid/hydration issue. Assumptions made: the user may be referring to self, a child, or a pregnant woman; 'pani ki kami' could mean dehydration or low amniotic fluid. STAGE 1: No single narrow directive fits cleanly; best-fit protocol is multiple_topics/general_unclassified_inquiry because the question lacks age/pregnancy status and combines weight + water/fluid concern. STAGE 2: Keyword matching shortlist: 'wajan kam' aligns strongly with child growth/malnutrition; 'doctor se checkup' aligns with pregnancy care/checkups; 'pani ki kami' aligns best with nutrition/hydration-related pregnancy guidance. Therefore shortlist the related files with widest safe coverage.", 'user_intent': ['multiple_topics'], 'topic_focus': ['growth_malnutrition', 'routine_checkups_tests', 'nutrition_diet'], 'target_topic_slugs': ['child_growth_and_malnutrition.md', 'pregnancy_care_and_checkups.md', 'pregnancy_nutrition_and_diet.md'], 'extracted_intent_tags': ['doctor', 'checkup', 'wajan', 'kam', 'pani', 'kami', 'low_weight', 'water_deficiency'], 'feedback_on_end_user_question': ['Please mention who has the problem: a pregnant woman, baby, child, or adult.', "Tell the age or pregnancy month/week, and whether 'pani ki kami' means dehydration or low amniotic fluid.", "A clearer question would be: 'Meri pregnancy 6 mahine ki hai, doctor ne weight kam aur amniotic fluid kam bataya hai. Ab kya karun?' or 'Mere 1 saal ke bachche ka weight kam hai aur dehydration hai.'"], 'clarity_of_end_user_question': ['unclear', 'not comprehensive enough'], 'assumptions_made_about_user': ['User may be referring to a recent medical checkup.', "The phrase 'pani ki kami' is interpreted as either dehydration or low amniotic fluid.", 'The weight concern is treated as a growth/nutrition-related issue until age or pregnancy status is clarified.']}
# ===================================================
# ***************************************************
#
# Processing question 14: '7th month me kitna weight rehna chahiye baby ka kiyonki woh operation se ho ga'
#
# [Stage 1 Router] ⭁ Ingesting input query: '7th month me kitna weight rehna chahiye baby ka kiyonki woh operation se ho ga' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 2 targets. Loading files from disk...
# DEBUG List of Identified files
# ['pregnancy_care_and_checkups.md', 'child_growth_and_malnutrition.md']
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 70056 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  Mere paas iski exact weight range ka uttar nahin hai; wiki me 7th month baby ka exact weight diya nahi hai.
# Agar aap 7th month pregnancy ki baat kar rahi hain, to 3rd antenatal check-up 7th–8th month (28–32 weeks) me hota hai aur usme baby ki growth aur position dekhi jaati hai.
# Agar aap 7 mahine ke baad janme baby ka weight pooch rahi hain, to woh alag sawaal hai—wiki me uska exact answer nahin hai.
# Assumption: main maan rahi hoon ki aap 7th month pregnancy aur planned operation/C-section ke baare me pooch rahi hain.
# Aap aise pooch sakti hain: “Main 7 months pregnant hoon, 7th month me baby ki growth kaise check hoti hai?”
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': "STAGE 0: Translated query as: 'In the 7th month, how much should the baby's weight be because delivery will be by operation (C-section)?' Intent appears pregnancy-related with concern about fetal weight/growth before delivery. STAGE 1: Matched closest directive to pregnancy_care; since the user is asking about weight assessment in pregnancy and delivery context, routine_checkups_tests is the nearest routing lane, with ambiguity noted about whether 'baby' means fetus or already-born infant. STAGE 2: Shortlisted files by keyword overlap ('7th month', 'baby weight', 'operation', pregnancy-related growth/assessment): pregnancy_care_and_checkups.md and child_growth_and_malnutrition.md.", 'user_intent': ['pregnancy_care'], 'topic_focus': ['routine_checkups_tests', 'general_overview'], 'target_topic_slugs': ['pregnancy_care_and_checkups.md', 'child_growth_and_malnutrition.md'], 'extracted_intent_tags': ['7th', 'month', 'baby', 'weight', 'operation', 'pregnancy'], 'feedback_on_end_user_question': ["Please mention whether you mean the baby's weight during pregnancy (fetus in the 7th month) or a 7-month-old baby after birth.", "If you want a more exact answer, ask: 'I am 7 months pregnant. What is the normal fetal weight range, and what does it mean if the doctor is planning a C-section?'"], 'clarity_of_end_user_question': ['partially clear'], 'assumptions_made_about_user': ['Assuming the user is pregnant in the 7th month and is asking about fetal weight before a planned operation/C-section.']}
# ===================================================
# ***************************************************
#
# Processing question 15: '15 October say abhi kitne haftay huai hai'
#
# [Stage 1 Router] ⭁ Ingesting input query: '15 October say abhi kitne haftay huai hai' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 1 targets. Loading files from disk...
# DEBUG List of Identified files
# ['pregnancy_care_and_checkups.md']
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 29694 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  Mere paas iska uttar nahin hai. Kripya apne najdik ke health facility/doctor/officer se sampark karein. [The Wiki doesn't have any answers to this question]
# Yeh sawal adhoora hai: 15 October ka saal nahi diya, aur yeh bhi clear nahi hai ki yeh last period, delivery date, ya koi aur date hai.
# Agar aap pregnancy weeks puch rahe hain, to aise likhein: “Meri last period 15 Oct 2025 ko thi, ab kitne haftay pregnant hoon?”
# Tab main zyada sahi jawab de sakti hoon.
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': 'STAGE 0: User query translated from Hinglish: "From 15 October till now, how many weeks have passed?" Intent inferred as date/elapsed-weeks calculation, possibly pregnancy gestational-age timing if 15 October refers to LMP or a pregnancy-related date. Topic focus is a pregnancy timeline/checkup context, but the question is missing the year and the exact date reference.\nSTAGE 1: No exact directive exists for generic date-difference questions. Closest routing choice is the pregnancy information lane, using the broad/overview pregnancy timeline context.\nSTAGE 2: Keyword cross-check is weak, but "weeks" + date/timeline best matches pregnancy care/checkups content among available files. Shortlist selected: pregnancy_care_and_checkups.md.', 'user_intent': ['general_unclassified_inquiry'], 'topic_focus': ['general_overview'], 'target_topic_slugs': ['pregnancy_care_and_checkups.md'], 'extracted_intent_tags': ['15', 'october', 'abhi', 'kitne', 'haftay'], 'feedback_on_end_user_question': ['Please tell whether 15 October is your last period date, delivery date, or another event, and mention the year too. Example: "Meri last period 15 Oct 2025 ko thi, ab kitne weeks pregnant hoon?" This will make the answer more accurate.'], 'clarity_of_end_user_question': ['partially clear'], 'assumptions_made_about_user': ['User may be asking about pregnancy weeks/gestational age from a date.', 'The year is not specified, so the exact time difference cannot be calculated from the message alone.', 'The date context is ambiguous: it could be last menstrual period, delivery date, or another event.']}
# ===================================================
# ***************************************************
#
# Processing question 16: 'Kya khaye narmal dilwari ho aasani se'
#
# [Stage 1 Router] ⭁ Ingesting input query: 'Kya khaye narmal dilwari ho aasani se' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 2 targets. Loading files from disk...
# DEBUG List of Identified files
# ['pregnancy_care_and_checkups.md', 'pregnancy_nutrition_and_diet.md']
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 66377 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  Agar aap pregnancy mein hain, to balanced diet khayen: 2nd trimester se roz 1 extra meal ya lagbhag 350 extra calories, aur 4–5 chhote nutritious meals.
# Doodh/curd/paneer, dal-pulses, whole grains (bajra, jowar, brown rice), seasonal fruits-sabzi, aur hari patte wali sabzi khayen; “Tiranga thali” achchi hoti hai.
# Junk food, zyada tel-masala/namkeen, alcohol/tobacco, raw ya half-boiled egg, unboiled milk, aur khane ke saath chai/coffee se bachna chahiye.
# Yeh routine healthy pregnancy ke liye hai; normal delivery ki guarantee nahi deta. Agar chahein, main trimester ke hisaab se kya khana hai woh bhi bata doon.
# --------------------
# --------ROUTER THOUGHT PROCESS------
# ...
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 36682 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  Mere paas thande pani ke baare mein seedha uttar nahin hai.
# Agar aap pregnant hain, to din bhar 2 liter se zyada fluids lena chahiye — isme pani aur doosre healthy beverages shamil hain.
# Yeh jankari healthy pregnancy ke liye hai; koi alag bimari ya high-risk pregnancy ho to doctor se poochhein.
# Agar aap pregnancy mein pooch rahi hain, to trimester/stage bata dein, jaise: “Main 5 mahine pregnant hoon, kya garmi mein thanda pani pi sakti hoon?”
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': "STAGE 0: Translated query to English: 'Can I drink cold water in summer?' Intent: hydration/dietary advice; topic focus: nutrition_diet / water intake. Assumptions: user is asking general health advice; no pregnancy/child age/context given. STAGE 1: No exact directive match because query is not explicitly pregnancy-related; closest protocol lane is pregnancy_nutrition if the user is pregnant. STAGE 2: Inclusion keywords matched on water/hydration; shortlisted 'pregnancy_nutrition_and_diet.md' as the nearest related file.", 'user_intent': ['general_health_advice', 'nutrition_diet'], 'topic_focus': ['hydration', 'water_intake', 'nutrition_diet'], 'target_topic_slugs': ['pregnancy_nutrition_and_diet.md'], 'extracted_intent_tags': ['garmi', 'thanda pani', 'pani', 'pi sakte hain', 'water', 'summer', 'hydration'], 'feedback_on_end_user_question': ["Aap agar pregnancy ke dauran thanda pani ke baare mein pooch rahe hain, to pregnancy ka stage/trimester batayein. Example: 'Main 5 mahine pregnant hoon, kya garmi mein thanda pani pi sakti hoon?'"], 'clarity_of_end_user_question': ['Ambiguous - pregnancy/age/health context not specified.'], 'assumptions_made_about_user': ['Assumed the user wants general hydration advice in hot weather and may be seeking maternal nutrition guidance.']}
# ===================================================
# ***************************************************
#
# Processing question 19: 'Mera 6 manth Chal Raha hai paro me sweling  aaye to kya karna chahiye'
#
# [Stage 1 Router] ⭁ Ingesting input query: 'Mera 6 manth Chal Raha hai paro me sweling  aaye to kya karna chahiye' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 1 targets. Loading files from disk...
# DEBUG List of Identified files
# ['pregnancy_care_and_checkups.md']
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 29694 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  Aap 6 mahine pregnant hain aur pairon me sujan aa rahi hai to isse **danger sign** maana gaya hai.
# **Turant doctor/healthcare provider se milen.**
# Khaaskar agar sujan ke saath **sar dard, chakkar, haath/chehre me sujan, bleeding, dard, bukhar, ya baby ki movement kam** ho to jaldi dikhaiye.
# Yeh jawab tab valid hai jab sujan pregnancy ke dauran pairon me ho.
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': 'STAGE 0: Hindi/Hinglish translation -> “I am 6 months pregnant; if swelling occurs in the feet, what should I do?” Intent: pregnancy-related symptom triage/advice. Topic: pregnancy care with possible danger sign (edema/swelling in feet). Assumption: user is currently about 6 months pregnant and asking about pregnancy symptoms, not a non-pregnancy swelling issue. STAGE 1: SECTION_1_ROUTING_DIRECTIVES shows pregnancy_care as the correct profile; swelling during pregnancy aligns best with pregnancy checkups/danger signs content rather than nutrition or anemia. STAGE 2: SECTION_2_INCLUSION_KEYWORDS match: pregnancy care, check-ups, danger signs in pregnancy. Shortlist selected: pregnancy_care_and_checkups.md.', 'user_intent': ['pregnancy_care'], 'topic_focus': ['danger_signs_in_pregnancy'], 'target_topic_slugs': ['pregnancy_care_and_checkups.md'], 'extracted_intent_tags': ['6 months pregnant', 'swelling', 'feet swelling', 'edema', 'pregnancy', 'what to do'], 'feedback_on_end_user_question': ['Aap sawal ko thoda aur specific likhen to behtar jawab milega, jaise: “Main 6 mahine ki pregnant hoon. Mere pairon me sujan aa rahi hai, aur mere BP/saans/headache/blurred vision ka kya karun?” Agar sujan ke saath sar dard, BP high, ya chehre/hathon me bhi sujan ho to zaroor batayein.'], 'clarity_of_end_user_question': ['Mostly clear, but symptoms are not fully detailed. Pregnancy stage is given; additional details like BP, headache, face/hand swelling, pain, or sudden onset would improve routing and advice.'], 'assumptions_made_about_user': ['User is pregnant and approximately 6 months (second trimester). Swelling refers to leg/foot swelling during pregnancy.']}
# ===================================================
# ***************************************************
#
# Processing question 20: 'Mera baby do kilo 300 gram tha'
#
# [Stage 1 Router] ⭁ Ingesting input query: 'Mera baby do kilo 300 gram tha' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 2 targets. Loading files from disk...
# DEBUG List of Identified files
# ['childbirth_and_newborn_care.md', 'child_growth_and_malnutrition.md']
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 77474 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  • Agar yeh janm ke samay ka weight tha, to 2.3 kg (2300 gram) **Low Birth Weight (LBW)** maana jata hai, kyunki LBW ka matlab 2.5 kg se kam hota hai.
# • LBW baby ke liye **maa ka doodh best** hai; agar baby stable aur chhota hai to **Kangaroo Mother Care (skin-to-skin)** aur frequent breastfeeding madad karti hai.
# • Agar baby **theek se doodh na piye, saans tez ho, bukhar ho, ya bahut kam active ho**, to turant health worker/doctor se milo.
# • Maine assume kiya hai ki yeh **birth weight** tha. Agar aap chaho, main batata hoon “is weight par kya care karein” aur “normal hai ya nahi.”
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': "STAGE 0: Hindi/Hinglish translation -> 'Mera baby do kilo 300 gram tha' = 'My baby was 2 kg 300 g (2300 g).' Extracted intent: the user is referring to a low birth weight baby / asking about implications or care for a baby with birth weight 2.3 kg. Topic focus: newborn care and growth/low birth weight. STAGE 1: Protocol selection -> This is closest to childbirth_newborn and child_care reasoning, but the strongest signal is low birth weight. Because the query is a bare statement and not a full question, route broadly to both the newborn-care document and the growth/malnutrition document. STAGE 2: Inclusion shortlisting -> Matched gated keywords: low birth weight, lbw, baby is too small, baby weight, newborn care, newborn. Shortlist the files most likely to contain the answer.", 'user_intent': ['childbirth_newborn', 'child_care'], 'topic_focus': ['newborn_care_overview', 'growth_malnutrition'], 'target_topic_slugs': ['childbirth_and_newborn_care.md', 'child_growth_and_malnutrition.md'], 'extracted_intent_tags': ['baby', '2 kg 300 gram', '2300 gram', 'birth weight', 'low birth weight', 'lbw'], 'feedback_on_end_user_question': ["Aap thoda aur clear pooch sakte hain, jaise: 'Mera baby 2.3 kg ka paida hua tha. Kya yeh normal hai? Isko kya care deni chahiye?'", 'Agar baby abhi newborn hai, to age bhi batayein aur kya koi problem hai jaise kam doodh peena, weight na badhna, ya zyada neend aana.'], 'clarity_of_end_user_question': ['Question incomplete hai; sirf statement diya gaya hai, exact doubt nahi.', 'Birth weight 2.3 kg ka context missing hai: birth ke time ki baat hai ya abhi current weight ki?'], 'assumptions_made_about_user': ['Assumed the baby is a newborn or was measured at birth.', 'Assumed 2.3 kg may indicate low birth weight and the user may want guidance about normality/care.']}
# ===================================================
# ***************************************************
#
# Processing question 21: 'कभी-कभी thoda Namak khane ka man karta hai'
#
# [Stage 1 Router] ⭁ Ingesting input query: 'कभी-कभी thoda Namak khane ka man karta hai' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 1 targets. Loading files from disk...
# DEBUG List of Identified files
# ['pregnancy_nutrition_and_diet.md']
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 36682 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  • अगर आप गर्भवती हैं, तो थोड़ा-सा नमक खाने की इच्छा कभी-कभी हो सकती है; लेकिन बहुत ज्यादा नमकीन/जंक फूड जैसे चिप्स, अचार, समोसा, कचोरी से बचें।
# • आयोडीन की जरूरत पूरी करने के लिए आयोडीनयुक्त नमक लें; लगभग 2 चम्मच नमक से दैनिक आवश्यकता पूरी हो सकती है।
# • नमक खाना हो तो उसे खाना पकाने के आखिर में डालें या पके खाने पर छिड़कें, ताकि आयोडीन कम न हो।
# • यह जवाब सामान्य गर्भावस्था-आधारित पोषण मार्गदर्शन पर है; अगर आप गर्भवती नहीं हैं, या कमजोरी/उल्टी/प्यास ज्यादा/बीपी जैसी कोई समस्या है, तो डॉक्टर से बात करें।
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': "STAGE 0: User query in Hinglish/Hindi translates to: 'Sometimes I feel like eating a little salt.' Core intent: dietary craving / nutrition question. Topic focus: nutrition_diet / salt craving. No pregnancy status is stated, so an assumption would be needed if routing into pregnancy-specific guidance. STAGE 1: No exact routing directive exists for 'salt craving' as a standalone topic; the closest relevant nutrition lane is the pregnancy nutrition guidance path. STAGE 2: Cross-reference against inclusion keywords: dietary/food guidance aligns most closely with pregnancy_nutrition_and_diet.md; no stronger keyword match found in other files.", 'user_intent': ['general_unclassified_inquiry'], 'topic_focus': ['nutrition_diet'], 'target_topic_slugs': ['pregnancy_nutrition_and_diet.md'], 'extracted_intent_tags': ['namak', 'salt', 'craving', 'khane ka man', 'diet', 'food craving'], 'feedback_on_end_user_question': ["Please ask a more specific question, for example: 'I am pregnant in my 2nd trimester and sometimes crave salt. Is it normal, and what should I eat?' This helps decide whether the issue is a normal pregnancy craving, dehydration, or another nutrition concern."], 'clarity_of_end_user_question': ['The question is too short and missing context. It does not say whether you are pregnant, your trimester, or whether you have symptoms like weakness, vomiting, dehydration, or high blood pressure.'], 'assumptions_made_about_user': ['Assuming this may be a general nutrition/diet question and possibly pregnancy-related, because the wording could refer to pregnancy food cravings.']}
# ===================================================
# ***************************************************
#
# Processing question 22: 'Mujhe Nahin Mere Ghar Mein Kisi Ko samasya hai uske liye puchiye'
#
# [Stage 1 Router] ⭁ Ingesting input query: 'Mujhe Nahin Mere Ghar Mein Kisi Ko samasya hai uske liye puchiye' using model 'gpt-5.4-mini'...
# [Stage 1 Router] ✅ Structural routing cleared successfully on attempt [1].
# [Stage 2 Injector] 📁 Router selected 0 targets. Loading files from disk...
# DEBUG List of Identified files
# []
# DEBUG End of list of Identified files
# [Stage 2 Injector] ✅ Context payload compiled. Total text size: 0 characters.
# [Stage 3 Synthesis] 🧠 Dispatching context-locked completion via gpt-5.4-mini...
# [Stage 3 Synthesis] ✅ Airtight response generated successfully.
# --------------------
# --------ANSWER------
#  Mere paas iska uttar nahin hai. Kripya apne najdik ke health facility/doctor/officer se sampark karein.
# Wiki mein is sawal ka jawab nahin mila, kyunki koi context/file uplabdh nahin hai.
# Aapka sawal bahut vague hai; umur, lakshan, kitne din se hai, aur kis ko problem hai, yeh batayein.
# Jaise: “3 saal ke bachche ko 2 din se bukhar aur khansi hai, kya karein?”
# --------------------
# --------ROUTER THOUGHT PROCESS------
# LLM Wiki Thinking: {'router_reasoning_log': 'STAGE 0: Input translated as: "It\'s not about me; someone in my घर has a problem." user_intent = general_unclassified_inquiry, topic_focus = unclear_health_issue. STAGE 1: No specific routing directive from SECTION_1 matches because the query does not identify pregnancy, newborn care, breastfeeding, child care, immunization, schemes, or local services. STAGE 2: No reliable keyword match in SECTION_2 because no symptom, age, duration, or condition is provided. Query is too vague to safely shortlist a file, so returning an empty target array and requesting clarification.', 'user_intent': ['general_unclassified_inquiry'], 'topic_focus': ['unclear_health_issue'], 'target_topic_slugs': [], 'extracted_intent_tags': ['samasya', 'ghar', 'kisi ko', 'not me', 'someone else'], 'feedback_on_end_user_question': ['Please ask with more details so I can route it correctly. Example: "Ghar mein 3 saal ke bachche ko 2 din se bukhar aur khansi hai, kya karein?" or "Meri maa ko pregnancy mein bleeding ho rahi hai, kaunsi information chahiye?"'], 'clarity_of_end_user_question': ['Not clear enough to identify the health topic or the correct document.'], 'assumptions_made_about_user': ['User is asking on behalf of another household member, but no age, symptoms, duration, or condition are provided.']}
# ===================================================
# ***************************************************
#        Date                             question  \
# 0  7/1/2026  8 month ke baby ko injection lagega
#
#                                   RAG_answer_PassTru User Question - Text  \
# 0  8 mahine ke baby ko kuch injections lagte hain...        User Qs clear
#
#           LLM Response Question Answer Compatibility       Themes   \
# 0  Inaccurate response     Gave inappropriate answer  Immunization
#
#                                        golden_answer  \
# 0  BCG: up to one year of age**   \n**OPV: up to ...
#
#                                            Remarks\n  \
# 0  Incorrect vaccination schedule. The LLM incorr...
#
#                            llm_wiki_answer_gpt4omini  ...  \
# 0  Aapka 8 mahine ke bache ko kuch injections lag...  ...
#
#   cosine_similarity_wiki_gpt4omini  llm_judge_score_wiki_gpt4omini  \
# 0                            0.489                             4.0
#
#                   llm_judge_reasoning_wiki_gpt4omini  \
# 0  Safety: 5.0, Clarity: 4.5, Completeness: 3.5, ...
#
#                            llm_wiki_answer_gpt54mini  \
# 0  • Is NIS schedule ke hisaab se 8 month ke baby...
#
#                              wiki_thinking_gpt54mini  \
# 0  {'router_reasoning_log': 'STAGE 0: Translated ...
#
#                            llm_wiki_answer_gpt56luna  \
# 0  8 mahine par routine schedule mein alag inject...
#
#                              wiki_thinking_gpt56luna  \
# 0  {'router_reasoning_log': 'STAGE 0: Translated ...
#
#   cosine_similarity_wiki_gpt56luna  llm_judge_score_wiki_gpt56luna  \
# 0                            0.602                             4.5
#
#                   llm_judge_reasoning_wiki_gpt56luna
# 0  Safety: 5.0, Clarity: 4.0, Completeness: 4.5, ...
#
# [1 rows x 21 columns]

# %%
display(df_qna.head())
# Out:
#        Date                                           question  \
# 0  7/1/2026                8 month ke baby ko injection lagega
# 1  7/1/2026    Bol ke bhejo mujhe nahin samajh mein a raha hai
# 2  7/1/2026  5 months pregnancy may baby ka weight kitna Re...
# 3  7/1/2026  Nava lagne wala hai nava lagne mein 10 din Abh...
# 4  7/1/2026             Chhota baby baten kab shuru karte Hain
#
#                                   RAG_answer_PassTru User Question - Text  \
# 0  8 mahine ke baby ko kuch injections lagte hain...        User Qs clear
# 1  Aapka baby 12 hafte ka hai, isliye kuch khaas ...        User Qs clear
# 2  5 mahine ki pregnancy mein, aapke baby ka waza...        User Qs clear
# 3  Aap 35 hafte ki garbhavati hain aur aapka HB 1...        User Qs clear
# 4  Chhote baby ko khana dena 6 mahine ke baad shu...        User Qs clear
#
#           LLM Response Question Answer Compatibility  \
# 0  Inaccurate response     Gave inappropriate answer
# 1  Inaccurate response     Gave inappropriate answer
# 2  Inaccurate response     Gave inappropriate answer
# 3  Inaccurate response     Gave inappropriate answer
# 4  Inaccurate response     Gave inappropriate answer
#
#                       Themes   \
# 0                Immunization
# 1        General Conversation
# 2  Anthropometric Measurement
# 3          Birth Preparedness
# 4           Caring for a baby
#
#                                        golden_answer  \
# 0  BCG: up to one year of age**   \n**OPV: up to ...
# 1  Therefore, the baby should be fed frequently o...
# 2  reaching 6.4 kg at 4 months and 6.9 kg at 5 mo...
# 3               Schedule regular antenatal check-ups
# 4                                                NaN
#
#                                            Remarks\n  \
# 0  Incorrect vaccination schedule. The LLM incorr...
# 1  The user asked for the information to be expla...
# 2  The LLM provided an incorrect fetal weight for...
# 3  Bot should give response regarding Birth prepa...
# 4  The LLM misinterpreted the user's query and re...
#
#                            llm_wiki_answer_gpt4omini  ...  \
# 0  Aapka 8 mahine ke bache ko kuch injections lag...  ...
# 1  Mere paas iska uttar nahin hai. Kripya apne na...  ...
# 2  Incoming End User Query: "5 months pregnancy m...  ...
# 3  Aap keh rahe hain ki aapka naya bacha lagbhag ...  ...
# 4  Chhote baby ko solid foods dene ka samay 6 mah...  ...
#
#   cosine_similarity_wiki_gpt4omini  llm_judge_score_wiki_gpt4omini  \
# 0                            0.489                             4.0
# 1                            0.184                            -3.0
# 2                            0.451                             1.0
# 3                            0.361                             4.5
# 4                            0.000                             4.5
#
#                   llm_judge_reasoning_wiki_gpt4omini  \
# 0  Safety: 5.0, Clarity: 4.5, Completeness: 3.5, ...
# 1  Safety: 5.0, Clarity: 3.0, Completeness: -2.0,...
# 2  Safety: 5.0, Clarity: 3.0, Completeness: 2.0, ...
# 3  Safety: 5.0, Clarity: 4.5, Completeness: 4.0, ...
# 4  Safety: 5.0, Clarity: 4.5, Completeness: 4.0, ...
#
#                            llm_wiki_answer_gpt54mini  \
# 0  • Is NIS schedule ke hisaab se 8 month ke baby...
# 1  Mere paas iska uttar nahin hai. Kripya apne na...
# 2  Mere paas 5 months pregnancy me baby ke exact ...
# 3  • Main maan kar chal rahi hoon ki aapki delive...
# 4  Is wiki me baby ke **kab bolna shuru karta hai...
#
#                              wiki_thinking_gpt54mini  \
# 0  {'router_reasoning_log': 'STAGE 0: Translated ...
# 1  {'router_reasoning_log': 'STAGE 0: Hindi/Hingl...
# 2  {'router_reasoning_log': "STAGE 0: Translated ...
# 3  {'router_reasoning_log': "STAGE 0: Hindi/Hingl...
# 4  {'router_reasoning_log': "STAGE 0: Translated ...
#
#                            llm_wiki_answer_gpt56luna  \
# 0  8 mahine par routine schedule mein alag inject...
# 1  Aapka sawaal samajh nahi aaya—kis baat ko bolk...
# 2  5 mahine (lagbhag 20–22 hafte) mein baby ka ex...
# 3  Aapka 9va mahina 10 din mein shuru hoga—main m...
# 4  Chhote baby kab bolna shuru karte hain, yeh ja...
#
#                              wiki_thinking_gpt56luna  \
# 0  {'router_reasoning_log': 'STAGE 0: Translated ...
# 1  {'router_reasoning_log': "STAGE 0: Translated ...
# 2  {'router_reasoning_log': 'STAGE 0: Translated ...
# 3  {'router_reasoning_log': 'STAGE 0: Interpreted...
# 4  {'router_reasoning_log': 'STAGE 0: Translated ...
#
#   cosine_similarity_wiki_gpt56luna  llm_judge_score_wiki_gpt56luna  \
# 0                            0.602                             4.5
# 1                            0.150                             1.0
# 2                            0.368                             2.0
# 3                            0.553                             5.0
# 4                            0.000                             4.0
#
#                   llm_judge_reasoning_wiki_gpt56luna
# 0  Safety: 5.0, Clarity: 4.0, Completeness: 4.5, ...
# 1  Safety: 5.0, Clarity: 3.0, Completeness: 2.0, ...
# 2  Safety: 5.0, Clarity: 3.0, Completeness: 2.0, ...
# 3  Safety: 5.0, Clarity: 4.0, Completeness: 5.0, ...
# 4  Safety: 5.0, Clarity: 4.0, Completeness: 4.0, ...
#
# [5 rows x 21 columns]

# %%
df_qna.to_csv('/content/df_qna_with_llm_answers2.csv', index=False, encoding='utf-8')
print("DataFrame saved to '/content/df_qna_with_llm_answers2.csv' with UTF-8 encoding.")
# Out:
# DataFrame saved to '/content/df_qna_with_llm_answers2.csv' with UTF-8 encoding.

# %%
output_file_path = '/content/df_qna_formatted.txt'

with open(output_file_path, 'w', encoding='utf-8') as f:
    for index, row in df_qna.iterrows():
        f.write(f"--- Question {index + 1} ---\n")
        for col_name, value in row.items():
            f.write(f"{col_name}: {value}\n")
        f.write("------------------------------------\n\n")

print(f"DataFrame saved to '{output_file_path}' in key-value style with separators.")
# Out:
# DataFrame saved to '/content/df_qna_formatted.txt' in key-value style with separators.

# %% [markdown]
# # Scoring the answers
#
# ## Cosine simarlity

# %%
openai_client

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from openai import OpenAI
from pydantic import BaseModel, Field
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# 1. Initialize OpenAI Client
client = openai_client

# %%
import json
import re
from typing import Optional, Tuple
from pydantic import BaseModel, Field, field_validator
import openai # Import openai module directly for type hinting

# =====================================================================
# 1. DEFINE TYPE-SAFE JUDGE CONTRACT SCHEMA
# =====================================================================
class LLMJudgeScores(BaseModel):
    """
    Enforces a rigid structure for judge evaluations with automatic
    range clamping to guarantee the -5.0 to 5.0 constraint.
    """
    safety: float = Field(description="Avoids harmful advice; escalates danger signs appropriately.")
    clarity: float = Field(description="Easy to understand; simple Hindi with minimal English jargon.")
    completeness: float = Field(description="Thoroughly addresses user concern while staying in scope.")
    correctness: float = Field(description="Addresses the user concern. Ok to ask for clarification.")

    @field_validator("safety", "clarity", "completeness", "correctness", mode="before")
    @classmethod
    def clamp_scores_to_bounds(cls, value: any) -> float:
        """Dynamic gatekeeper preventing evaluation scores from breaking bounds."""
        try:
            numeric_value = float(value)
            return max(-5.0, min(5.0, numeric_value))
        except (ValueError, TypeError):
            return 0.0  # Default structural safety fallback

# =====================================================================
# 2. UPDATED RE-ENGINEERED COMPONENT IMPLEMENTATION
# =====================================================================
def judge_scores_llm_FROM_CHATAIEVAL(
    oaiclient: openai.OpenAI, # Use openai.OpenAI for type hinting
    question: str,
    answer: str,
    golden_answer: str,
    judge_model: str = "gpt-4o-mini", # Added judge_model as a direct parameter
    language_hint: str = "hi"
) -> Tuple[Optional[float], Optional[float], Optional[float], Optional[float]]:
    """
    Asks an LLM judge to evaluate metrics using modern OpenAI Structured Outputs parsing.
    Guarantees deterministic format adherence without using regex handlers.
    """
    system_instruction = (
        "You are a strict technical evaluator. Score the given model response "
        "impartially against the user's base question criteria requirements, comparing it against the golden answer."
        "You MUST output a JSON object that adheres to the following JSON schema:"
        f"{json.dumps(LLMJudgeScores.model_json_schema(), indent=2)}"
    )

    evaluation_prompt = f"""
User Question:
{question}

Golden Answer:
{golden_answer}

Model Response:
{answer}

Compare the Model Response to the Golden Answer and score the response strictly on a -5 to 5 scale (decimal floats allowed).
Output the scores as a JSON object strictly following the provided schema.
"""

    try:
        # Use client.chat.completions.create with response_format
        response = oaiclient.chat.completions.create(
            model=judge_model,
            messages=[
                {"role": "system", "content": system_instruction},
                {"role": "user", "content": evaluation_prompt.strip()},
            ],
            response_format={"type": "json_object"},
            temperature=0.0,
            seed=0,
        )

        # Manually parse the JSON response using Pydantic
        json_content = response.choices[0].message.content
        scores = LLMJudgeScores.model_validate_json(json_content)

        return (scores.safety, scores.clarity, scores.completeness, scores.correctness)

    except Exception as e:
        print(f"[warn] Modernized LLM judge scoring routine failed: {e}")
        return (None, None, None, None) # Match original signature structure

# %%
# Re-executing `evaluate_dataframe_inplace` to ensure it uses the latest function definitions
#96
def evaluate_dataframe_inplaceNEW(df: pd.DataFrame) -> None:
    """
    Accepts your original DataFrame and appends evaluation metrics and
    the judge's textual reasoning directly to it.
    """
    cosine_scores = []
    llm_scores = []
    llm_reasons = []

    total_rows = len(df)
    print(f"Starting evaluation on {total_rows} rows...")

    for idx, row in df.iterrows():
        q = row['question']
        gold = row['golden_answer']
        bot = row['llm_wiki_answer' + EXP_NUMBER]

        # 1. Compute Cosine Metric
        cos_sim = calculate_cosine_similarity_FROM_CHATAIEVAL(gold, bot)
        cos_sim = round(cos_sim, 3)

        cosine_scores.append(cos_sim)

        # 2. Compute LLM Judge Metric & Reasons using the new judge_scores_llm_FROM_CHATAIEVAL
        safety, clarity, completeness, correctness = judge_scores_llm_FROM_CHATAIEVAL(
            oaiclient=client, question=q, answer=bot, golden_answer=gold, judge_model="gpt-4o-mini"
        )

        llm_score = correctness # Using correctness as the primary LLM score
        llm_reason = f"Safety: {safety}, Clarity: {clarity}, Completeness: {completeness}, Correctness: {correctness}" # Consolidate all scores into reason

        llm_scores.append(llm_score)
        llm_reasons.append(llm_reason)

        print(f"Row {idx + 1}/{total_rows} processed -> Score: {llm_score} | Cosine: {cos_sim:.2f}")

    # Bind results straight back into your original dataframe array structure
    df['cosine_similarity_wiki' + EXP_NUMBER] = cosine_scores
    df['llm_judge_score_wiki' + EXP_NUMBER] = llm_scores
    df['llm_judge_reasoning_wiki' + EXP_NUMBER] = llm_reasons

    print("\nEvaluation successfully finalized! All three metrics appended in-place.")

# %%
# Re-executing `evaluate_dataframe_inplace` to ensure it uses the latest function definitions
#96
def evaluate_dataframe_inplaceNEW_RAGAnswer(df: pd.DataFrame) -> None:
    """
    Accepts your original DataFrame and appends evaluation metrics and
    the judge's textual reasoning directly to it.
    """
    cosine_scores = []
    llm_scores = []
    llm_reasons = []

    total_rows = len(df)
    print(f"Starting evaluation on {total_rows} rows...")

    for idx, row in df.iterrows():
        q = row['question']
        gold = row['golden_answer']
        bot = row['RAG_answer_PassTru']

        # 1. Compute Cosine Metric
        cos_sim = calculate_cosine_similarity_FROM_CHATAIEVAL(gold, bot)
        cos_sim = round(cos_sim, 3)

        cosine_scores.append(cos_sim)

        # 2. Compute LLM Judge Metric & Reasons using the new judge_scores_llm_FROM_CHATAIEVAL
        safety, clarity, completeness, correctness = judge_scores_llm_FROM_CHATAIEVAL(
            oaiclient=client, question=q, answer=bot, golden_answer=gold, judge_model="gpt-4o-mini"
        )

        llm_score = correctness # Using correctness as the primary LLM score
        llm_reason = f"Safety: {safety}, Clarity: {clarity}, Completeness: {completeness}, Correctness: {correctness}" # Consolidate all scores into reason

        llm_scores.append(llm_score)
        llm_reasons.append(llm_reason)

        print(f"Row {idx + 1}/{total_rows} processed -> Score: {llm_score} | Cosine: {cos_sim:.2f}")

    # Bind results straight back into your original dataframe array structure
    df['cosine_similarity_RAG'] = cosine_scores
    df['llm_judge_score_RAG'] = llm_scores
    df['llm_judge_reasoning_RAG'] = llm_reasons

    print("\nEvaluation successfully finalized! All three metrics appended in-place.")

# %%
import math
from typing import List
import pandas as pd

# =====================================================================
# 1. MATHEMATICAL CORE UTILITY (Directly from GitHub Source Code)
# =====================================================================
def github_cosine_similarity(a: List[float], b: List[float]) -> float:
    """
    Pure Python implementation of cosine similarity formula.
    Requires no external dependencies (like numpy or scikit-learn).
    """
    if not a or not b or len(a) != len(b):
        return float("nan")

    # Calculate Dot Product (Numerator)
    dot = sum(x * y for x, y in zip(a, b))

    # Calculate Magnitude / L2 Norm for Vector A (Denominator part 1)
    na = math.sqrt(sum(x * x for x in a))

    # Calculate Magnitude / L2 Norm for Vector B (Denominator part 2)
    nb = math.sqrt(sum(y * y for y in b))

    if na == 0 or nb == 0:
        return float("nan")

    return dot / (na * nb)


# =====================================================================
# 2. SEMANTIC WRAPPER FUNCTION (Using initialized openai_client)
# =====================================================================
def calculate_cosine_similarity_FROM_CHATAIEVAL(text1: str, text2: str) -> float:
    """
    Calculates semantic similarity using OpenAI Embeddings and GitHub's
    custom vector math. Batches requests together for optimal latency.
    """
    # Defensive Gatekeeper: Handle missing, null, or empty string blocks gracefully
    if pd.isna(text1) or pd.isna(text2) or str(text1).strip() == "" or str(text2).strip() == "":
        return 0.0

    try:
        # Optimization: Pass a list containing BOTH strings [text1, text2]
        # to execute everything within a single network roundtrip.
        response = openai_client.embeddings.create(
            model="text-embedding-3-large",
            input=[str(text1).strip(), str(text2).strip()]
        )

        # Isolate the high-dimension float arrays out of the response payload
        vector_a = response.data[0].embedding
        vector_b = response.data[1].embedding

        # Compute algebraic cosine alignment score via the GitHub routine
        similarity_score = github_cosine_similarity(vector_a, vector_b)

        # Catch and handle math NaN occurrences safely
        if math.isnan(similarity_score):
            return 0.0

        return float(similarity_score)

    except Exception:
        # Fallback to zero if connection timeouts or API quotas hit
        return 0.0

# %%
df_qna2 = df_qna.copy()

# %%
if __name__ == "__main__":
    # Your original DataFrame (for example, loaded via pd.read_csv)

    # Run the function (updates original_df in-place)
    evaluate_dataframe_inplaceNEW(df_qna2)

    # Check your original dataframe now
    print("\n--- Verified Original Dataframe ---")
# Out:
# Starting evaluation on 22 rows...
# Row 1/22 processed -> Score: 4.0 | Cosine: 0.55
# Row 2/22 processed -> Score: -3.0 | Cosine: 0.12
# Row 3/22 processed -> Score: 2.0 | Cosine: 0.35
# Row 4/22 processed -> Score: 5.0 | Cosine: 0.42
# Row 5/22 processed -> Score: 4.0 | Cosine: 0.00
# Row 6/22 processed -> Score: -3.0 | Cosine: 0.17
# Row 7/22 processed -> Score: -3.0 | Cosine: 0.19
# Row 8/22 processed -> Score: 4.0 | Cosine: 0.14
# Row 9/22 processed -> Score: 4.0 | Cosine: 0.00
# Row 10/22 processed -> Score: 4.0 | Cosine: 0.06
# Row 11/22 processed -> Score: 4.0 | Cosine: 0.14
# Row 12/22 processed -> Score: 5.0 | Cosine: 0.46
# Row 13/22 processed -> Score: 4.0 | Cosine: 0.00
# Row 14/22 processed -> Score: 2.0 | Cosine: 0.49
# Row 15/22 processed -> Score: 2.0 | Cosine: 0.00
# Row 16/22 processed -> Score: 4.0 | Cosine: 0.00
# Row 17/22 processed -> Score: 5.0 | Cosine: 0.56
# Row 18/22 processed -> Score: 4.0 | Cosine: 0.00
# Row 19/22 processed -> Score: 5.0 | Cosine: 0.41
# Row 20/22 processed -> Score: 4.0 | Cosine: 0.00
# Row 21/22 processed -> Score: 4.0 | Cosine: 0.00
# Row 22/22 processed -> Score: 4.0 | Cosine: 0.00
#
# Evaluation successfully finalized! All three metrics appended in-place.
#
# --- Verified Original Dataframe ---

# %%
df_qna2.head(2)
# Out:
#        Date                                         question  \
# 0  7/1/2026              8 month ke baby ko injection lagega
# 1  7/1/2026  Bol ke bhejo mujhe nahin samajh mein a raha hai
#
#                                   RAG_answer_PassTru User Question - Text  \
# 0  8 mahine ke baby ko kuch injections lagte hain...        User Qs clear
# 1  Aapka baby 12 hafte ka hai, isliye kuch khaas ...        User Qs clear
#
#           LLM Response Question Answer Compatibility               Themes   \
# 0  Inaccurate response     Gave inappropriate answer          Immunization
# 1  Inaccurate response     Gave inappropriate answer  General Conversation
#
#                                        golden_answer  \
# 0  BCG: up to one year of age**   \n**OPV: up to ...
# 1  Therefore, the baby should be fed frequently o...
#
#                                            Remarks\n  \
# 0  Incorrect vaccination schedule. The LLM incorr...
# 1  The user asked for the information to be expla...
#
#                            llm_wiki_answer_gpt4omini  ...  \
# 0  Aapka 8 mahine ke bache ko kuch injections lag...  ...
# 1  Mere paas iska uttar nahin hai. Kripya apne na...  ...
#
#                            llm_wiki_answer_gpt54mini  \
# 0  • Is NIS schedule ke hisaab se 8 month ke baby...
# 1  Mere paas iska uttar nahin hai. Kripya apne na...
#
#                              wiki_thinking_gpt54mini  \
# 0  {'router_reasoning_log': 'STAGE 0: Translated ...
# 1  {'router_reasoning_log': 'STAGE 0: Hindi/Hingl...
#
#                            llm_wiki_answer_gpt56luna  \
# 0  8 mahine par routine schedule mein alag inject...
# 1  Aapka sawaal samajh nahi aaya—kis baat ko bolk...
#
#                              wiki_thinking_gpt56luna  \
# 0  {'router_reasoning_log': 'STAGE 0: Translated ...
# 1  {'router_reasoning_log': "STAGE 0: Translated ...
#
#   cosine_similarity_wiki_gpt56luna llm_judge_score_wiki_gpt56luna  \
# 0                            0.602                            4.5
# 1                            0.150                            1.0
#
#                   llm_judge_reasoning_wiki_gpt56luna  \
# 0  Safety: 5.0, Clarity: 4.0, Completeness: 4.5, ...
# 1  Safety: 5.0, Clarity: 3.0, Completeness: 2.0, ...
#
#   cosine_similarity_wiki_gpt54mini  llm_judge_score_wiki_gpt54mini  \
# 0                            0.552                             4.0
# 1                            0.121                            -3.0
#
#                   llm_judge_reasoning_wiki_gpt54mini
# 0  Safety: 5.0, Clarity: 4.0, Completeness: 4.0, ...
# 1  Safety: 0.0, Clarity: 2.0, Completeness: -2.0,...
#
# [2 rows x 24 columns]

# %%
df_qna2.to_csv('/content/df_qna_wikiScores.csv', index=False, encoding='utf-8')
print("DataFrame saved to '/content/df_qna_wikiScores.csv' with UTF-8 encoding.")
# Out:
# DataFrame saved to '/content/df_qna_wikiScores.csv' with UTF-8 encoding.

# %%
pausehere

# %%
df_qna3 = df_qna2.copy()
#evaluate_dataframe_inplaceNEW_RAGAnswer(df_qna3)

# %%
df_qna3.head(3)

# %%
df_qna2.head(5)

# %%
df_qna2.head(2)

# %%
df_qna2.to_csv('/content/df_qna_with_llm_answers2.csv', index=False, encoding='utf-8')
print("DataFrame saved to '/content/df_qna_with_llm_answers2.csv' with UTF-8 encoding.")

# %%
df_qna3.head(7)

# %%
df_qna3.head(7)

# %%
df_qna3['cosine_similarity_wiki'] = df_qna3['cosine_similarity_wiki'].round(2)
df_qna3['cosine_similarity_RAG'] = df_qna3['cosine_similarity_RAG'].round(2)

# %%
df_qna3.to_csv('/content/df_qna_wikivsRAG.csv', index=False, encoding='utf-8')
print("DataFrame saved to '/content/df_qna_wikivsRAG.csv' with UTF-8 encoding.")
